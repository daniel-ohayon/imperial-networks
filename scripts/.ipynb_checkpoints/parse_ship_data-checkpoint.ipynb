# %%
import requests
from bs4 import BeautifulSoup
import pdb
import re
import json
import time
from collections import Counter

# %%
import requests

# Reverse-engineered by looking at the request done in Chrome Network tab
# **Headers > Form Data** is the interesting part (POST data submitted by the form)
# Right-click > export to cURL then copy to https://curl.trillworks.com/
# to get the Python requests syntax

def get_ship_html(ship_id):
    headers = {
        'Connection': 'keep-alive',
        'Cache-Control': 'max-age=0',
        'Origin': 'https://www.memoiredeshommes.sga.defense.gouv.fr',
        'Upgrade-Insecure-Requests': '1',
        'Content-Type': 'application/x-www-form-urlencoded',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36',
        'Sec-Fetch-User': '?1',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'navigate',
        'Referer': 'https://www.memoiredeshommes.sga.defense.gouv.fr/fr/arkotheque/client/mdh/compagnie_des_indes/armement_navires.php?action=1&todo=modif_recherche',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.9,fr-FR;q=0.8,fr;q=0.7',
    }

    data = {
      'action': '1',
      'todo': 'rechercher',
      'r_sel_navire': ship_id,
      'form_rech_date_debut': '1600',
      'form_rech_date_fin': '1800',
      'r_sel_nom_capitaine': '',
      'r_sel_lieu_depart_bat': '',
      'r_sel_lieu_destination_bat': '',
      'r_sel_typearmateur': '',
      'r_sel_proprietaire': ''
    }

    return requests.post('https://www.memoiredeshommes.sga.defense.gouv.fr/fr/arkotheque/client/mdh/compagnie_des_indes/armement_navires.php', headers=headers, data=data).content

# %%
# Parse ship IDs from the selector HTML on the search page
def parse_all_ship_ids():
    headers = {
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36',
        'Sec-Fetch-User': '?1',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'Sec-Fetch-Site': 'none',
        'Sec-Fetch-Mode': 'navigate',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'en-US,en;q=0.9,fr-FR;q=0.8,fr;q=0.7',
    }

    search_page = requests.get('https://www.memoiredeshommes.sga.defense.gouv.fr/fr/arkotheque/client/mdh/compagnie_des_indes/armement_navires.php', headers=headers).content

    t = BeautifulSoup(search_page, 'html.parser')
    ship_options = t.find(id="r_sel_navire").find_all("option")
    ship_ids = {opt.attrs.get('value') for opt in ship_options}
    return sorted([x for x in ship_ids if x is not None and x != ''])

# %%
def parse_ship_journeys(ship_html):
    t = BeautifulSoup(ship_html, 'html.parser')
    journeys_data = []
    journeys = t.find_all('fieldset', class_='detail_navire')
    for j in journeys:
        header = j.find(class_='retrait_navire')
        dates_elem = header.find('small')
        if dates_elem is not None:
            dates = header.find('small').text.split('-')
            start_date, end_date = dates[0], dates[1] if len(dates) > 1 else dates[0]
        else:
            start_date, end_date = None, None
        itinerary = header.find('h3')
        stops = itinerary.contents[0].split(' → ') if itinerary is not None else []
        ship_name_elem = j.find('h2')
        ship_name = ship_name_elem.contents[0].split('\t')[0] if ship_name_elem is not None else None

        table_data = []
        table = j.find("div", id=re.compile("^detail_campagne_"))
        if table is not None:
            table_rows = table.find_all("tr")
            for row in table_rows[1:]:  # `1:` because we skip header
                entries = row.find_all("td")
                table_data.append({
                    'location': entries[0].text, 
                    'status': entries[1].text, 
                    'date': entries[2].text
                })

        journey_data = {
            'start_date': start_date,
            'end_date': end_date,
            'stops': stops,
            'ship_name': ship_name,
            'ship_log': table_data
        }
        journeys_data.append(journey_data)
    return journeys_data

# %%
list(parse_all_ship_ids())[:10]
# Out:
# ['Q+ly6HM=',
#  'Q291cmV1cg==',
#  'Q291cnJpZXIgZGUgQm91cmJvbg==',
#  'Q291cnJpZXIgZGUgbJLubGUgZGUgRnJhbmNl',
#  'Q291cnJpZXIgZJJPcmzpYW5z',
#  'Q29sb21iZQ==',
#  'Q29sb24=',
#  'Q29sb25pZQ==',
#  'Q29tbWVyY2U=',
#  'Q29tcGFnbmllIGRlcyBJbmRlcw==']

# %%
# Initialization
ship_ids = parse_all_ship_ids()
ships_data = {}

# %%
# Expensive compute
for i, ship_id in enumerate(ship_ids, 1):
    if ship_id in ships_data:
        print(f"Skipping {ship_id} since we already have the data")
        continue
    print(f"Fetching data for {ship_id} ({i}/{len(ship_ids)})...")

    ship_html = get_ship_html(ship_id)
    ship_journeys = parse_ship_journeys(ship_html)
    if ship_journeys:
        ships_data[ship_id] = ship_journeys
    else:
        print("No data found! Did we get throttled?")
    time.sleep(30)  # to avoid getting throttled by the website
# Out:
# Fetching data for Q+ly6HM= (1/752)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-952aeac76059> in <module>()
#      12     else:
#      13         print("No data found! Did we get throttled?")
# ---> 14     time.sleep(30)  # to avoid getting throttled by the website
#
# KeyboardInterrupt:

# %%
# with open('ship_data.json', 'w', encoding='utf8') as f:
#     json.dump(ships_data, f, ensure_ascii=False)
# Out:
# /Users/daniel/repos/imperial-networks

# %% [markdown]
# ## Start from here if you want to skip data fetching

# %%
with open('ship_data.json', encoding='utf8') as f:
    ships_data = json.load(f)

# %%
from collections import Counter
ship_log_entries = Counter()
stops = Counter()
for k, v in ships_data.items():
    for entry in v:
        for stop in entry['stops']:
            stops[stop] += 1
        for e in entry['ship_log']:
            ship_log_entries[e['location']] += 1

# %%
LOCATIONS = {
    'Isle Bourbon & Isle of France': ['Mascareignes', 'îles de France et de Bourbon', 'île Bourbon', 'Port-Louis, île de France', 'île de France', 'Île de France'] ,
    'Senegal': ['Sénégal', 'Sénégal et Gorée', 'Gorée', 'Cap-Vert', 'Juda et côtes de Guinée', 'Juda'],
    'Caribbean': ['Saint-Domingue', 'Martinique', 'Antilles', 'Cap-Français', 'Saint-Louis, St-Domingue', 'Léogane', 'Port-au-Prince', 'La Grenade (île de)', 'Petit-Goâve, St-Domingue', 'Guadeloupe'],
    'Louisiana': ['Louisiane', 'Ascension', 'Nouvelle-Orléans', 'Biloxy, Louisiane'],
    'France': ['Le Havre', 'Nantes', 'Bordeaux', 'Saint-Malo', 'Brest', 'La Rochelle', 'Marseille', 'Rochefort', 'Sète', 'Bayonne', 'Honfleur', 'Dunkerque', 'Rouen', 'Groix', 'Lorient', 'Toulon', 'Paimboeuf', 'Belle-île-en-Mer'],
    'Madagascar': ['Madagascar', 'Port-Louis', 'Anjouan', 'Fort-Dauphin, Madagascar', 'Sainte-Marie, Madagascar', 'baie de St-Augustin, Madagsascar'],  # TODO
    'India': ['Inde', 'Karaikal', 'Karikal', 'Pondichéry', 'Bengale', 'Calicut', 'Goa', 'Chandernagor', 'Négapatam', 'Madras', 'sur le Gange'],
    'New France': ['Louisbourg (île Royale), Canada', 'Saint-Pierre et Miquelon', 'Terre-Neuve'],
    'Guyana': ['Guyane', 'Cayenne'],
}

# %%
LINKS = []

def normalize_location(location):
    matches = []
    # in cases like "Mascareignes et Madagascar", we want to
    # retain both 'Mascareignes' (Bourbon) and 'Madagascar' as separate stops
    # That's why we return a list as opposed to a single name.
    for key, synonyms in LOCATIONS.items():
        for synonym in synonyms:
            if synonym in location:
                matches.append((key, synonym))
                break
    # If >1 stop, return stops in their order of appearance in the input
    # eg "Inde et Mascareignes" => ['India', 'Bourbon']
    # but "Mascareignes et Madagascar" => ['Bourbon', 'Madagascar']
    res = [m[0] for m in sorted(matches, key=lambda m: location.index(m[1]))]
    return res

def normalize_itinerary(itinerary):
    # normalize locations, skip unknown locations, no contiguous duplicates
    result = []
    for stop in itinerary:
        next_stops = normalize_location(stop)
        if len(result) == 0 or len(result) > 0 and all(s != result[-1] for s in next_stops):
            result += next_stops
    return result if len(result) > 1 else []

def make_preview_str(entry):
    # In some cases the ship_log has more accurate data that can contradict this itinerary
    # for example with COURRIER DE BOURBON 
    return f"{entry['ship_name']} ({entry['start_date']}-{entry['end_date']}): " + ' → '.join(entry['stops'])

def ship_entry_to_links(entry, stops):
    links = []
    for i in range(1, len(stops)):
        links.append({
            'from': stops[i-1],
            'to': stops[i],
            # we only have the start/end years for the full journey
            # not the intermediary stops, so we use the end_date for
            # all stops after departure
            'from_date': entry['start_date'] if i == 1 else entry['end_date'],
            'to_date': entry['end_date'],
            'preview': make_preview_str(entry),
            'tag': 'with_metropole' if stops[i] == 'France' or stops[i-1] == 'France' else 'between_colonies'
        })
    return links
  
        
# UNKNOWN_STOPS_COUNTER.most_common(100)

# %%
for k, v in ships_data.items():
    for entry in v:
        
        stops_v1 = normalize_itinerary(entry['stops'])
        stops_v2 = normalize_itinerary([e['location'] for e in entry['ship_log']])

        # use the itinerary with the most detail out of the two
        stops = stops_v1 if len(stops_v1) > len(stops_v2) else stops_v2
        LINKS += ship_entry_to_links(entry, stops)

# %%
def print_obj(obj):
    print(json.dumps(obj, ensure_ascii=False, indent=2))

print_obj(LINKS[:5])
# Out:
# [
#   {
#     "from": "France",
#     "to": "Isle Bourbon & Isle of France",
#     "from_date": "1771",
#     "to_date": "1774",
#     "preview": "CÉRÈS (1771-1774): Lorient → Mascareignes et Madagascar → Cap de Bonne-Espérance → Mascareignes → Lorient",
#     "tags": "with_metropole"
#   },
#   {
#     "from": "Isle Bourbon & Isle of France",
#     "to": "Madagascar",
#     "from_date": "1774",
#     "to_date": "1774",
#     "preview": "CÉRÈS (1771-1774): Lorient → Mascareignes et Madagascar → Cap de Bonne-Espérance → Mascareignes → Lorient",
#     "tags": "within_colonies"
#   },
#   {
#     "from": "Madagascar",
#     "to": "Isle Bourbon & Isle of France",
#     "from_date": "1774",
#     "to_date": "1774",
#     "preview": "CÉRÈS (1771-1774): Lorient → Mascareignes et Madagascar → Cap de Bonne-Espérance → Mascareignes → Lorient",
#     "tags": "within_colonies"
#   },
#   {
#     "from": "Isle Bourbon & Isle of France",
#     "to": "France",
#     "from_date": "1774",
#     "to_date": "1774",
#     "preview": "CÉRÈS (1771-1774): Lorient → Mascareignes et Madagascar → Cap de Bonne-Espérance → Mascareignes → Lorient",
#     "tags": "with_metropole"
#   },
#   {
#     "from": "France",
#     "to": "Caribbean",
#     "from_date": "1781",
#     "to_date": "1782",
#     "preview": "COUREUR (1781-1782): Lorient → Martinique et Cap-Français → Lorient",
#     "tags": "with_metropole"
#   }
# ]

# %%
# !cat ship_links.json | json-to-js > data/ships/links.js
# !echo "const SHIPS_LINKS = $(cat data/ships/links.js);" > data/ships/links.js
# !rm ship_links.json

# %%
with open ('ship_links.json', 'w', encoding='utf-8') as f:
    json.dump(LINKS, f, ensure_ascii=False)

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 6]
from collections import defaultdict, Counter

# cumulative ship departures over time
x = list(np.arange(1700, 1801, 5))
y = [0 for _ in x]
for link in LINKS:
    for i in range(len(x)):
        if int(link['from_date']) <= x[i]:
            y[i] += 1

plt.xticks(np.arange(1700, 1800, 10))

plt.plot(x, y)

# %%
# non-cumulative
by_year = Counter()
for link in LINKS:
    year = int(link['from_date'])
    if year <= 1760:
        by_year[year] += 1
x, y = [], []
for a, b in sorted(by_year.items(), key= lambda item: item[0]):
    x.append(a) ; y.append(b)

plt.xticks(np.arange(1710, 1761, 5))
plt.scatter(x, y)
plt.plot(x, y)

# %%
for k, v in ships_data.items():
    for entry in v:
        for stop in entry['stops']:
            if 'Guyane' in stop:
                print_obj(entry)
        for e in entry['ship_log']:
            if 'Guyane' in stop:
                print_obj(entry)
# Out:
# {
#   "start_date": "1724",
#   "end_date": "1726",
#   "stops": [
#     "Le Havre",
#     "Lorient",
#     "Juda",
#     "Guyane",
#     "Lorient"
#   ],
#   "ship_name": "EXPÉDITION",
#   "ship_log": [
#     {
#       "location": "Le Havre",
#       "status": "armement",
#       "date": "06/08/1724"
#     },
#     {
#       "location": "Le Havre",
#       "status": "départ",
#       "date": "08/08/1724"
#     },
#     {
#       "location": "Groix",
#       "status": "arrivée",
#       "date": "17/08/1724"
#     },
#     {
#       "location": "Port-Louis",
#       "status": "arrivée",
#       "date": "18/08/1724"
#     },
#     {
#       "location": "Lorient",
#       "status": "départ",
#       "date": "04/09/1724"
#     },
#     {
#       "location": "Gorée",
#       "status": "arrivée",
#       "date": "04/10/1724"
#     },
#     {
#       "location": "Gorée",
#       "status": "départ",
#       "date": "17/10/1724"
#     },
#     {
#       "location": "Mesurade",
#       "status": "arrivée",
#       "date": "09/12/1724"
#     },
#     {
#       "location": "Mesurade",
#       "status": "départ",
#       "date": "18/12/1724"
#     },
#     {
#       "location": "Juda",
#       "status": "arrivée",
#       "date": "11/01/1725"
#     },
#     {
#       "location": "Juda",
#       "status": "départ",
#       "date": "11/05/1725"
#     },
#     {
#       "location": "île du Prince (Principe)",
#       "status": "arrivée",
#       "date": "09/06/1725"
#     },
#     {
#       "location": "île du Prince (Principe)",
#       "status": "départ",
#       "date": "27/06/1725"
#     },
#     {
#       "location": "Cayenne",
#       "status": "arrivée",
#       "date": "26/08/1725"
#     },
#     {
#       "location": "Cayenne",
#       "status": "départ vers le",
#       "date": "15/04/1726"
#     },
#     {
#       "location": "Lorient",
#       "status": "désarmement",
#       "date": "16/06/1726"
#     }
#   ]
# }

# %%
len(ships_data)
# Out:
# 751

# %% [markdown]
# # Analyzing most common routes [April 2019]

# %%
n_voyages = 0
min_date = 2000
max_date = 0
for ship_entries in ships_data.values():
    n_voyages += len(ship_entries)
    for e in ship_entries:
        if e['start_date']:
            min_date = min(min_date, int(e['start_date']))
            max_date = max(max_date, int(e['end_date']))

print(f"""
Analyzing {n_voyages} voyages from {len(ships_data)} French ships,
between {min_date} and {max_date}
""")
# Out:
# Analyzing 2158 voyages from 751 French ships,
# between 1713 and 1792

# %%
# Most common stops
stops_count = Counter()
n_total = 0
n_current = 0
for ship_entries in ships_data.values():
    for entry in ship_entries:
        for stop in entry['stops']:
            stops_count[stop] += 1
            n_total += 1

# TODO: stopped annotation at côte de Coromandel  (95%)

for stop, freq in stops_count.most_common(500):
    n_current += freq
    print(stop, '-', freq, '-', f"{round(n_current/n_total*100, 2)}%")
# Out:
# Lorient - 2505 - 36.45%
# Mascareignes - 225 - 39.72%
# Inde et Mascareignes - 224 - 42.98%
# Sénégal - 162 - 45.34%
# Saint-Domingue - 155 - 47.59%
# Louisiane - 117 - 49.29%
# Le Havre - 116 - 50.98%
# Cap de Bonne-Espérance - 114 - 52.64%
# Cadix - 107 - 54.2%
# Chine - 106 - 55.74%
# Sénégal et Gorée - 105 - 57.27%
# Ascension - 104 - 58.78%
# Port-Louis - 101 - 60.25%
# Inde - 93 - 61.6%
# Nantes - 92 - 62.94%
# ? - 89 - 64.24%
# Bordeaux - 82 - 65.43%
# Saint-Malo - 80 - 66.59%
# Martinique - 71 - 67.63%
# Brest - 66 - 68.59%
# Gorée - 65 - 69.53%
# La Rochelle - 62 - 70.44%
# Antilles - 60 - 71.31%
# Marseille - 59 - 72.17%
# île de France - 49 - 72.88%
# Rochefort - 46 - 73.55%
# Brésil - 44 - 74.19%
# vaisseau de côte - 44 - 74.83%
# île de France ? - 40 - 75.41%
# Pondichéry - 38 - 75.96%
# service des fermes - 37 - 76.5%
# Anjouan - 36 - 77.03%
# Cap-Vert - 32 - 77.49%
# Ténériffe - 30 - 77.93%
# cabotage - 30 - 78.36%
# Sainte-Hélène - 27 - 78.76%
# Île de France - 27 - 79.15%
# Juda et côtes de Guinée - 25 - 79.51%
# Sète - 25 - 79.88%
# Sainte-Hélène et Ascension - 24 - 80.23%
# Madagascar et Mascareignes - 23 - 80.56%
# Lisbonne - 23 - 80.9%
# Cap-Français - 22 - 81.22%
# Mascareignes et Madagascar - 21 - 81.52%
# Bordeaux ? - 21 - 81.83%
# Juda - 21 - 82.13%
# Madagascar - 20 - 82.42%
# La Corogne - 19 - 82.7%
# Marseille ? - 17 - 82.95%
# En service en Inde - 16 - 83.18%
# Angola - 15 - 83.4%
# Saint-Domingue ? - 15 - 83.62%
# Bayonne - 14 - 83.82%
# Hambourg - 14 - 84.02%
# Bengale - 14 - 84.23%
# La Rochelle ? - 13 - 84.42%
# îles de France et de Bourbon ? - 13 - 84.61%
# course ? - 12 - 84.78%
# Malaga - 12 - 84.96%
# Escadre d'Aché pour l'Inde, deuxième division - 12 - 85.13%
# Honfleur - 12 - 85.3%
# Inde ? - 12 - 85.48%
# Arguin - 12 - 85.65%
# Santiago - 12 - 85.83%
# Fernando de Noronha - 11 - 85.99%
# Nantes ? - 11 - 86.15%
# petit cabotage ? - 11 - 86.31%
# Inde et Mascareignes, Madagascar - 10 - 86.45%
# petit cabotage - 10 - 86.6%
# Dunkerque - 10 - 86.75%
# Rouen - 10 - 86.89%
# Vannes - 10 - 87.04%
# Paimboeuf - 9 - 87.17%
# Moka - 9 - 87.3%
# Saint-Pierre et Miquelon - 9 - 87.43%
# Amérique ? - 8 - 87.55%
# Escadre d'Aché pour l'Inde, première division - 8 - 87.66%
# Terre-Neuve - 8 - 87.78%
# Portendick - 8 - 87.89%
# Pérou - 8 - 88.01%
# En service au Sénégal - 8 - 88.13%
# Nantes/Paimboeuf - 8 - 88.24%
# Amérique - 8 - 88.36%
# Prise espagnole capturée à Pensacola - 7 - 88.46%
# Barcelone - 7 - 88.56%
# Audierne - 7 - 88.67%
# Cayenne - 7 - 88.77%
# au devant des vaisseaux - 7 - 88.87%
# Navire de Nantes affrété par la Compagnie des Indes - 7 - 88.97%
# Alicante - 7 - 89.07%
# Guinée - 6 - 89.16%
# Pondichéry ? - 6 - 89.25%
# Vigo - 6 - 89.34%
# En service en Inde et dans l’Océan Indien - 6 - 89.42%
# aux ordres du roi - 6 - 89.51%
# île Bourbon - 6 - 89.6%
# Lorient pour l'Inde - 6 - 89.68%
# cabotage ? - 6 - 89.77%
# Louisbourg - 6 - 89.86%
# Toulon - 6 - 89.95%
# En service en Inde et dans l’océan Indien - 6 - 90.03%
# Terre-Neuve ? - 6 - 90.12%
# Baltimore - 6 - 90.21%
# côte d’Afrique ? - 6 - 90.3%
# Santiago (Cap-Vert) - 6 - 90.38%
# Concarneau - 6 - 90.47%
# Madagascar, Inde et Mascareignes - 5 - 90.54%
#  Lorient - 5 - 90.62%
# Madère - 5 - 90.69%
# Port-au-Prince - 5 - 90.76%
# Sète ? - 5 - 90.83%
# Bengale ? - 5 - 90.91%
# Saint-Domingue et Louisiane - 5 - 90.98%
# Granville - 5 - 91.05%
# grand cabotage - 5 - 91.12%
# Dieppe - 5 - 91.2%
# Chandernagor - 5 - 91.27%
# Guadeloupe - 5 - 91.34%
# Saint-Malo ? - 5 - 91.42%
# Lorient pour le Sénégal - 5 - 91.49%
# Vaisseau de Nantes affrété par la Compagnie des Indes - 5 - 91.56%
# Sénégal et Portendick - 4 - 91.62%
# Mozambique - 4 - 91.68%
# Roscoff - 4 - 91.74%
# Chine ? - 4 - 91.79%
# Londres - 4 - 91.85%
# Prise capturée en Inde par le  - 4 - 91.91%
# Belle-Île - 4 - 91.97%
# Açores - 4 - 92.03%
# Mascareignes et Inde - 4 - 92.08%
# Cap-Français ? - 4 - 92.14%
# Martinique ? - 4 - 92.2%
# Expédition d’Estaing - 4 - 92.26%
# Le Passage - 4 - 92.32%
# îles de France et de Bourbon - 4 - 92.38%
# Canaries - 4 - 92.43%
# Cadix ? - 4 - 92.49%
# Dunkerque ? - 3 - 92.54%
# France - 3 - 92.58%
# Vaisseau du roi armé par la Compagnie des Indes - 3 - 92.62%
# Morlaix - 3 - 92.67%
# Douarnenez - 3 - 92.71%
# Cherbourg - 3 - 92.75%
# cap de Bonne-Espérance - 3 - 92.8%
# Mozambique ? - 3 - 92.84%
# Angleterre - 3 - 92.89%
# Escadre de Froger de l'Éguille pour l'Inde - 3 - 92.93%
# En service à l’île de France - 3 - 92.97%
# escadre d’Anville - 3 - 93.02%
# Cabotage - 3 - 93.06%
# Virginie - 3 - 93.1%
# course - 3 - 93.15%
# Refondue à Lorient - 3 - 93.19%
# Rio de Janeiro - 3 - 93.23%
# Batavia - 3 - 93.28%
# Acheté à Batavia - 3 - 93.32%
# En service en Inde, vaisseau de côte - 3 - 93.37%
# Québec - 3 - 93.41%
# Boston - 3 - 93.45%
# Espagne - 3 - 93.5%
# Indes - 3 - 93.54%
# Canada - 3 - 93.58%
# Sumatra - 3 - 93.63%
# Philippines - 3 - 93.67%
# Lorient/Port-Louis - 3 - 93.71%
# Île Bourbon - 3 - 93.76%
# En service en Inde et dans l'Océan Indien - 3 - 93.8%
# Cayenne ? - 3 - 93.85%
# cap de Bonne-Espérance ? - 3 - 93.89%
# Vaisseau du roi affrété par la Compagnie des Indes - 3 - 93.93%
# Port-Louis Lorient - 2 - 93.96%
# False Bay - 2 - 93.99%
# En service dans l'Océan Indien - 2 - 94.02%
# Inde, Madagascar et Mascareignes - 2 - 94.05%
# Paimpol - 2 - 94.08%
# Côtes de Guinée - 2 - 94.11%
# Bénodet - 2 - 94.14%
# grand cabotage ? - 2 - 94.17%
# Amsterdam - 2 - 94.19%
# Lorient pour l’Inde - 2 - 94.22%
# Marennes - 2 - 94.25%
# Prise écossaise capturée par le  - 2 - 94.28%
# Dieppe ? - 2 - 94.31%
# côte de Guinée - 2 - 94.34%
# Carthagène - 2 - 94.37%
# Bourgneuf - 2 - 94.4%
# Arguin, Sénégal et Gorée - 2 - 94.43%
# pêche ? - 2 - 94.46%
# Terres Australes - 2 - 94.49%
# Manille - 2 - 94.51%
# Le Havre ? - 2 - 94.54%
# Tabago (Tobago) - 2 - 94.57%
# Pauillac - 2 - 94.6%
# Philadelphie ? - 2 - 94.63%
# Rochefort ? - 2 - 94.66%
# Arguin, Portendick - 2 - 94.69%
# Bristol - 2 - 94.72%
# côte du sud-ouest africain - 2 - 94.75%
# La Grenade - 2 - 94.78%
# Prise anglaise - 2 - 94.81%
# Saint-Pierre et Miquelon ? - 2 - 94.83%
# Sénégal et Arguin - 2 - 94.86%
# En service aux Mascareignes - 2 - 94.89%
# Ascencion - 2 - 94.92%
# Nantes/Paimbœuf - 2 - 94.95%
# Belle-île - 2 - 94.98%
# Saint-Paul de Luanda (Angola) - 2 - 95.01%
# Port-Louis/Lorient - 2 - 95.04%
# côte de Coromandel - 2 - 95.07%
# La Rochelle ? - 2 - 95.1%
# Mascareigne - 2 - 95.13%
# Inde et Mascareignes, Moka - 2 - 95.15%
# Lorient ? - 2 - 95.18%
# Sénégal ? - 2 - 95.21%
# Renversement à Lorient de l’équipage de la  - 2 - 95.24%
# Acheté à Brest par la Compagnie des Indes - 2 - 95.27%
# Île de Ré - 2 - 95.3%
# Lorient pour la course - 2 - 95.33%
# Prise capturée en Inde par l’escadre de Saint-Georges - 2 - 95.36%
# Martin Vas - 2 - 95.39%
# Falmouth - 2 - 95.42%
# Antilles ? - 2 - 95.45%
# Moka, Inde et Mascareignes - 2 - 95.48%
# Sierra Leone - 2 - 95.5%
# Brest ? - 2 - 95.53%
# Quimper - 2 - 95.56%
# Navire de Lorient affrété par la Compagnie des Indes - 2 - 95.59%
# Navire de Nantes affrété puis acheté par la Compagnie des Indes - 2 - 95.62%
# Armement à confirmer - 2 - 95.65%
# En service aux Mascareignes et dans l’Océan Indien - 2 - 95.68%
# Les Cayes Saint-Louis ? - 2 - 95.71%
# Corvette de Lorient affrétée puis achetée par la Compagnie des Indes - 2 - 95.74%
# Lorient pour l'Amérique - 2 - 95.77%
# Canton - 2 - 95.8%
# Navire de Lorient armé par la Compagnie des Indes - 2 - 95.82%
# Prise anglaise capturée à ? - 2 - 95.85%
# pêche en mer du sud ? - 2 - 95.88%
# Martinique et Cap-Français - 1 - 95.9%
# Nantes Paimboeuf - 1 - 95.91%
# banc de l’Étoile, Madagascar - 1 - 95.93%
# canal de Mozambique - 1 - 95.94%
# Barfleur - 1 - 95.96%
# Nantes/Paimboeuf/Mindin - 1 - 95.97%
# Mascareignes et Batavia - 1 - 95.98%
# Norvège - 1 - 96.0%
# côte de Guinée ? - 1 - 96.01%
# Berguen - 1 - 96.03%
# Gijon - 1 - 96.04%
# Funchal (Madère) - 1 - 96.06%
# Salou - 1 - 96.07%
# Saint-Nazaire - 1 - 96.09%
# Bordeaux  pour l'Inde - 1 - 96.1%
# Le Croisic ? - 1 - 96.12%
# Basse-Terre, Guadeloupe - 1 - 96.13%
# Océan Indien - 1 - 96.14%
# Santiago de Cassem, Portugal - 1 - 96.16%
# Lorient (transporte l’équipage de la  - 1 - 96.17%
# Philadelphie - 1 - 96.19%
# Cap de Bonne-Espérance, île de France, Batavia - 1 - 96.2%
# Hollande - 1 - 96.22%
# Équipage transporté à Brest par la gabarre la  - 1 - 96.23%
# Sénégal et Guinée - 1 - 96.25%
# Mascareignes, Madagascar et Inde - 1 - 96.26%
# Vaisseau de côte en service aux Indes - 1 - 96.28%
# Pont-Labbé - 1 - 96.29%
# Livourne - 1 - 96.3%
# Auray - 1 - 96.32%
# Vannes (?) - 1 - 96.33%
# Mataro - 1 - 96.35%
# Salo - 1 - 96.36%
# Vinaros - 1 - 96.38%
# armée pour la Louisiane, revenue après une épidémie - 1 - 96.39%
# En service à l’île de France et dans l’océan Indien, voyage de découverte - 1 - 96.41%
# île Saint-Jean - 1 - 96.42%
# Île Saint-Jean, Canada ? - 1 - 96.44%
# Prise capturée en Inde par la  - 1 - 96.45%
# En service aux Mascareignes et dans l’océan Indien - 1 - 96.46%
# Prise anglaise capturée dans l’Atlantique par l’escadre d’Aché - 1 - 96.48%
# Les Sables-d’Olonne ? - 1 - 96.49%
# Saisi pour trafic illégal à l’île de France et conduit à l’île Bourbon par l’ - 1 - 96.51%
# Équipage transporté de Saint-Malo à Hambourg par le  - 1 - 96.52%
# Sainte-Hélène et Ascencion - 1 - 96.54%
# Inde (?) et Mascareignes - 1 - 96.55%
# Portendick et Arguin - 1 - 96.57%
# Malacca - 1 - 96.58%
# pour la course en Guinée - 1 - 96.6%
# Carthagène (Colombie) - 1 - 96.61%
# Porto Bello (Panama) - 1 - 96.62%
# Frégate du roi affrétée par la Compagnie des Indes - 1 - 96.64%
# Prise anglaise saisie pour trafic illégal à Portendick - 1 - 96.65%
# Juda, île du Prince - 1 - 96.67%
# Prise anglaise capturée par le  - 1 - 96.68%
# Bombay - 1 - 96.7%
# Inde et Moka - 1 - 96.71%
# Achetée ou cédée par le roi à la Compagnie des Indes - 1 - 96.73%
# Acheté à Saint-Malo par la Compagnie des Indes - 1 - 96.74%
# Mascareignes et Indes - 1 - 96.76%
# Chibouctou (Acadie) - 1 - 96.77%
# Le Croisic - 1 - 96.78%
# Lorient pour Setúbal au Portugal - 1 - 96.8%
# La Hougue - 1 - 96.81%
# Frégate affrétée par la Compagnie des Indes - 1 - 96.83%
# pêche - 1 - 96.84%
# Virginie ? - 1 - 96.86%
# Saint-Valery-sur-Somme - 1 - 96.87%
# Landerneau - 1 - 96.89%
# Prise anglaise achetée à Brest par la Compagnie des Indes - 1 - 96.9%
# Paimbœuf - 1 - 96.92%
# Sénégal, Gorée et Portendick - 1 - 96.93%
# Sénégal ? - 1 - 96.94%
# Sainte-Hélène  - 1 - 96.96%
# Angola et Guinée - 1 - 96.97%
# escorte pour le cap Finisterre - 1 - 96.99%
# idef - 1 - 97.0%
# Le Conquet - 1 - 97.02%
# Lorient pour Pondichéry - 1 - 97.03%
# Échoué près de Saint-Nazaire et renfloué - 1 - 97.05%
# Acheté à Batavia en juin 1760 ou pris aux Anglais en février 1760 - 1 - 97.06%
# Capturé puis vendu à Batavia - 1 - 97.08%
# Amérique française - 1 - 97.09%
# côte d’Afrique - 1 - 97.1%
# île Grande - 1 - 97.12%
# Saint-Pierre, Martinique ? - 1 - 97.13%
# Baie de Biscay - 1 - 97.15%
# Course - 1 - 97.16%
# Flamborough Head - 1 - 97.18%
# Kernevel - 1 - 97.19%
# Île de France ? - 1 - 97.21%
# bateau de côte - 1 - 97.22%
# Nantes - ? - 1 - 97.24%
# cabotage (Nantes et Saint-Malo) - 1 - 97.25%
#  Saint-Domingue - 1 - 97.26%
# Sénégal, Portendick et Gorée - 1 - 97.28%
# Prise anglaise capturée en Inde - 1 - 97.29%
# Liverpool pour la Gambie - 1 - 97.31%
# île de Ré - 1 - 97.32%
# Majorque - 1 - 97.34%
#  Chine - 1 - 97.35%
# Lorient pour l'Inde et les Mascareignes - 1 - 97.37%
# Île Royale et  Louisbourg - 1 - 97.38%
# Prise anglaise capturée au large de Madras - 1 - 97.4%
# Louisbourg (Acadie) - 1 - 97.41%
# Cap-Français (St-Domingue) - 1 - 97.42%
# Mascareignes et Pondichéry - 1 - 97.44%
# Cochinchine - 1 - 97.45%
# journalier de rade - 1 - 97.47%
# Mascareignes et cap de Bonne-Espérance - 1 - 97.48%
# Mahé et côte ouest de l’Inde - 1 - 97.5%
# Acheté en Hollande par la Compagnie des Indes - 1 - 97.51%
#  Antilles ? - 1 - 97.53%
# Saint-Petersbourg - 1 - 97.54%
# Prise hollandaise capturée à la hauteur de Potendick par le  - 1 - 97.56%
# Confisqué à Saint-Paul île Bourbon - 1 - 97.57%
# Équipage transporté de Nantes à Hambourg par le  - 1 - 97.58%
# Lorient pour les Mascareignes - 1 - 97.6%
# Poulo-Condor - 1 - 97.61%
# Madagascar et Comores - 1 - 97.63%
# Lorient ou La Rochelle ? - 1 - 97.64%
# île de France et Inde ? - 1 - 97.66%
# Deptford - 1 - 97.67%
# Île Grande - 1 - 97.69%
# Mascareignes et Seychelles - 1 - 97.7%
# Birmanie -Inde - 1 - 97.72%
# Redon - 1 - 97.73%
# Brest (?) - 1 - 97.74%
# Ténérife - 1 - 97.76%
# Prise capturée au large du Brésil par l’ - 1 - 97.77%
#  Brésil - 1 - 97.79%
# la Grenade - 1 - 97.8%
# Navire de Saint-Malo affrété par la Compagnie des Indes - 1 - 97.82%
# armé pour l'Inde - 1 - 97.83%
# armé pour les Mascareignes, capturé par les Anglais - 1 - 97.85%
# St-Domingue - 1 - 97.86%
# Martinique (?) - 1 - 97.88%
# Saint-Domigue - 1 - 97.89%
# Prise anglaise capturée en Inde par l’escadre de Saint-Georges - 1 - 97.9%
# Le Havre ? - 1 - 97.92%
# escorte pour le Cap Finisterre - 1 - 97.93%
# Guyane - 1 - 97.95%
# expédition d’Estaing - 1 - 97.96%
# Prise anglaise capturée par l’escadre d’Aché devant Négapatam - 1 - 97.98%
# course dans l’Océan Indien - 1 - 97.99%
#  ? - 1 - 98.01%
# Équipage renversé à Lorient sur l’ - 1 - 98.02%
# Navire du Havre affrété par la Compagnie des Indes - 1 - 98.04%
# Saiint-Domingue - 1 - 98.05%
# côtes de Guinée et Juda - 1 - 98.06%
# Juda et île du Prince - 1 - 98.08%
# Île d'Aix - 1 - 98.09%
# Québec ? - 1 - 98.11%
# Lisbonne ? - 1 - 98.12%
# Île de France et Mozambique - 1 - 98.14%
# Navire affrété par la Compagnie des Indes - 1 - 98.15%
# vaisseau affrété par la Compagnie des Indes - 1 - 98.17%
# Lorient pour l'île de France - 1 - 98.18%
# Vaisseau de La Rochelle affrété pour transporter des troupes - 1 - 98.2%
# Guinée ou Sénégal - 1 - 98.21%
# Racheté par la Compagnie - 1 - 98.22%
# Civita-Vecchia - 1 - 98.24%
#  au devant des vaisseaux - 1 - 98.25%
#  Gorée - 1 - 98.27%
# Équipage parti par voie de terre de Saint-Malo - 1 - 98.28%
# Vaisseau du roi armé pour protéger les vaisseaux  de la Compagnie des Indes - 1 - 98.3%
# Prise anglaise capturée aux Antilles par le  - 1 - 98.31%
# Nouvelle Écosse - 1 - 98.33%
# Affrété pour transporter l’équipage de l’ - 1 - 98.34%
# Affrété pour transporter l’équipage du  - 1 - 98.36%
# Navire de Bordeaux acheté à l'île Maurice par Nicolas Hilaire Comarmond - 1 - 98.37%
# Équipage transporté de Saint-Malo à Londres - 1 - 98.38%
# Affrétée pour transporter l’équipage de la  - 1 - 98.4%
# Saint-Pierre (Martinique) - 1 - 98.41%
# armé pour l’océan Indien, resté à Lorient - 1 - 98.43%
# Saint-Domingue et Amérique - 1 - 98.44%
# Edington - 1 - 98.46%
# Prise anglaise capturée par l’escadre d’Aché - 1 - 98.47%
# Escadre d'Aché pour l'Inde - 1 - 98.49%
# Inde et Mascareignes, Siam - 1 - 98.5%
# Prise capturée dans le golfe Persique par le  - 1 - 98.52%
# Java - 1 - 98.53%
# Lorient Cap-Vert - 1 - 98.55%
# Quillebeuf - 1 - 98.56%
# Pontevedra - 1 - 98.57%
# Bayonne ? - 1 - 98.59%
# Pornic ? - 1 - 98.6%
# Birmanie - 1 - 98.62%
# Prise anglaise capturée à Mascate par le  - 1 - 98.63%
# Paimboeuf/Nantes - 1 - 98.65%
# Affrétée pour rapatrier l’équipage du  - 1 - 98.66%
# Calcutta vers Madras - 1 - 98.68%
# Ascension - - 1 - 98.69%
# Saint-Malo ? - 1 - 98.71%
# Côte de Guinée - 1 - 98.72%
# Radoubée à Lorient - 1 - 98.73%
#  Portendick, Sénégal et Gorée - 1 - 98.75%
# Luanda - 1 - 98.76%
# Foulpointe, Madagascar - 1 - 98.78%
# Petit Goave - 1 - 98.79%
# côte de Saint-Domingue - 1 - 98.81%
# Côte occidentale d’Afrique - 1 - 98.82%
# Gottembourg - 1 - 98.84%
# Fécamp - 1 - 98.85%
#  vaisseau de côte - 1 - 98.87%
# Cadix et côtes d’Espagne - 1 - 98.88%
# Vera Cruz (Mexique) - 1 - 98.89%
# En service dans l’océan Indien - 1 - 98.91%
# Affrété pour rapatrier une partie de l’équipage de la  - 1 - 98.92%
# Pacifique - 1 - 98.94%
# Redon ? - 1 - 98.95%
# Porto - 1 - 98.97%
# Sénégal et Gorée, Portendick - 1 - 98.98%
# Sénégal et Gorée, Portendick  - 1 - 99.0%
# Navire privé en service dans l'Océan Indien - 1 - 99.01%
# Frégate de Saint-Malo affrétée puis achetée par la Compagnie des Indes - 1 - 99.03%
# Santander - 1 - 99.04%
# Martinique et Guadeloupe - 1 - 99.05%
# Buenos-Ayres - 1 - 99.07%
# Armement  à confirmer - 1 - 99.08%
# Prise anglaise capturée et incendiée à Bender-Abbas par l’ - 1 - 99.1%
#  Madagascar, Mascareignes et Inde - 1 - 99.11%
# Canaries ? - 1 - 99.13%
# Prise anglaise capturée à la côte de Coromandel par l’escadre de La Bourdonnais - 1 - 99.14%
# En service dans l’Océan Indien - 1 - 99.16%
# En service en Inde (peut-être le précédent) - 1 - 99.17%
# Vaisseau affrété par la Compagnie de Chine - 1 - 99.19%
# Moka et Mascareignes - 1 - 99.2%
# Affrété par la Compagnie de Saint-Domingue - 1 - 99.21%
# Prise anglaise capturée par l’ - 1 - 99.23%
# Acheté à Saint-Malo par la Compagnie des Indes au sr Magon de La Balue - 1 - 99.24%
# Renfloué et réparé dans le port de La Pallice - 1 - 99.26%
#  Mascareignes - 1 - 99.27%
# Cap Ortegal - 1 - 99.29%
# Vaisseau de Nantes affrété puis racheté par la Compagnie des Indes - 1 - 99.3%
# Mindin - 1 - 99.32%
# Mascareignes et Océan Indien - 1 - 99.33%
# Sénégal et Gambie - 1 - 99.35%
# Siam - 1 - 99.36%
# Échoué au départ puis renfloué à Lorient - 1 - 99.37%
# Portendick, Sénégal et Gorée - 1 - 99.39%
# Trieste - 1 - 99.4%
# Prise anglaise capturée à Madras ? - 1 - 99.42%
# Madras - 1 - 99.43%
# Affrétée pour transporter l’équipage du  - 1 - 99.45%
# Inde et Mascareigne - 1 - 99.46%
# Pointe-à-Pitre, Guadeloupe - 1 - 99.48%
# Prise capturée au large de Saint-Domingue par la  - 1 - 99.49%
# Avarié par un abordage et réparé à Lorient de mars à fin avril 1758 - 1 - 99.51%
# Falmouth, Angleterre ? - 1 - 99.52%
# Équipage transporté du Havre à Hambourg par la  - 1 - 99.53%
# Comores - 1 - 99.55%
# Québec- Lorient - 1 - 99.56%
# Rouen ? - 1 - 99.58%
# Île Grande (Brésil) - 1 - 99.59%
# Lorient- Vannes - 1 - 99.61%
# Île d’Aix - 1 - 99.62%
# En service à Madagascar et dans l’océan Indien - 1 - 99.64%
# Prise capturée par le  - 1 - 99.65%
# Portsmouth - 1 - 99.67%
# îles françaises de l’Amérique ? - 1 - 99.68%
# Martinique et Saint-Domingue - 1 - 99.69%
# Frégate de Nantes affrétée puis achetée par la Compagnie des Indes - 1 - 99.71%

# %%
LOCATIONS = {
    'Isle Bourbon & Isle of France': ['Mascareignes', 'îles de France et de Bourbon', 'île Bourbon', 'Port-Louis, île de France', 'île de France', 'Île de France', 'Moka'] ,
    'North African coast': ['Sénégal', 'Sénégal et Gorée', 'Gorée', 'Juda et côtes de Guinée', 'Juda', 'Portendick', 'Guinée', 'Mozambique', 'côte d’Afrique'],
    'South African coast': ['Angola', 'côte du sud-ouest africain', 'Saint-Paul de Luanda (Angola)'],
    
    'Caribbean': ['Saint-Domingue', 'Martinique', 'Antilles', 'Cap-Français', 'Saint-Louis, St-Domingue', 'Léogane', 'Port-au-Prince', 'La Grenade (île de)', 'Petit-Goâve, St-Domingue', 'Guadeloupe', 'La Grenade'],
    'British Caribbean': ['Tabago'],

    'Louisiana': ['Louisiane', 'Ascension', 'Nouvelle-Orléans', 'Biloxy, Louisiane'],
    
    'France': ['Le Havre', 'Nantes', 'Bordeaux', 'Saint-Malo', 'Brest', 'La Rochelle', 'Marseille', 'Rochefort', 'Sète', 'Bayonne', 'Honfleur', 'Dunkerque', 'Rouen', 'Groix', 'Lorient', 'Toulon', 'Paimboeuf', 'Belle-île-en-Mer', 'Audierne', 'Concarneau', 'Granville', 'Dieppe', 'Roscoff', 'Belle-Île', 'Morlaix', 'Douarnenez', 'Cherbourg', 'Paimpol', 'Bénodet', 'Marennes', 'Bourgneuf', 'Pauillac'],
    
    'Iberia': ['Cadix', 'Lisbonne', 'La Corogne', 'Malaga', 'Barcelone', 'Alicante', 'Vigo'],
    
    'Germany': ['Hambourg'],
    'China': ['Chine'],
    
    'England': ['Londres', 'Angleterre', 'Bristol'],

    'Madagascar': ['Madagascar', 'Port-Louis', 'Anjouan', 'Fort-Dauphin, Madagascar', 'Sainte-Marie, Madagascar', 'baie de St-Augustin, Madagsascar'],
    'India': ['Inde', 'Karaikal', 'Karikal', 'Pondichéry', 'Bengale', 'Calicut', 'Goa', 'Chandernagor', 'Négapatam', 'Madras', 'sur le Gange'],
    'New France': ['Louisbourg (île Royale), Canada', 'Saint-Pierre et Miquelon', 'Terre-Neuve', 'Louisbourg', 'Québec'],
    'British North America': ['Baltimore', 'Virginie', 'Boston', 'Philadelphie'],
    'Guyana': ['Guyane', 'Cayenne'],
    'South America': ['Brésil', 'Fernando de Noronha', 'Amérique', 'Pérou', 'Rio de Janeiro', 'Carthagène'],  # TODO Amerique ?
    'Cape of Good Hope': ['Cap de Bonne-Espérance', 'False Bay'],
    'South Atlantic islands': ['Ascension', 'Ascencion', 'Sainte-Hélène'],
    'North Atlantic islands': ['Ténériffe', 'Cap-Vert', 'Arguin', 'Santiago', 'Madère', 'Açores', 'Canaries'],
    'South-East Asia': ['Batavia', 'Sumatra', 'Philippines', 'Manille', ],

}

# %%
INDIAN_OCEAN_KEYS = [
    'Isle Bourbon & Isle of France',
    'Madagascar',
    'India',
    'South-East Asia'
]
ATLANTIC_KEYS = [
    'Cape of Good Hope',
    'South America',
    'North African coast',
    'Caribbean',
    'Louisiana',
    'New France',
    'Guyana',
    'Iberia',
    'North Atlantic islands',
    'South Atlantic islands',
    'South African coast',
    'British North America',
    'England',
]

INDIAN_OCEAN_STOPS = [
    k for key in INDIAN_OCEAN_KEYS for  k in LOCATIONS[key]
]
ATLANTIC_STOPS = [
    k for key in ATLANTIC_KEYS + ['France'] for  k in LOCATIONS[key]
]
ATLANTIC_STOPS_MINUS_FRANCE = [
    k for key in ATLANTIC_KEYS for  k in LOCATIONS[key]
]

def is_valid_stop(stop, valid_stops):
    for s in valid_stops:
        if s in stop:
            return True
    return False

def first_valid_stop_idx(stops, valid_stops):
    for i, stop in enumerate(stops):
        if is_valid_stop(stop, valid_stops):
            return i
    return -1

def has_atlantic(route, with_metropole=True):
    valid_stops = ATLANTIC_STOPS if with_metropole else ATLANTIC_STOPS_MINUS_FRANCE
    return any(is_valid_stop(s, valid_stops) for s in route)

def has_indian_ocean(route):
    return any(is_valid_stop(s, INDIAN_OCEAN_STOPS) for s in route)

def has_atlantic_before_indian(route):
    first_indian = first_valid_stop_idx(route, INDIAN_OCEAN_STOPS)
    first_atlantic = first_valid_stop_idx(route, ATLANTIC_STOPS_MINUS_FRANCE)
    if first_indian < 0 or first_atlantic < 0:
        return False
    return first_atlantic < first_indian

def has_indian_before_atlantic(route):
    first_indian = first_valid_stop_idx(route, INDIAN_OCEAN_STOPS)
    first_atlantic = first_valid_stop_idx(route, ATLANTIC_STOPS)
    if first_indian < 0 or first_atlantic < 0:
        return False
    return first_indian < first_atlantic

def ratio(n1, n2):
    return f"{n1}/{n2} ({round(n1/n2*100)}%)"

# %%
# Function to facilitate calculations of the type:
# "out of all trips with some property, how many had some other property?"
def trips_ratio(in_numerator, in_denominator):
    numerator = 0
    denominator = 0
    for ship_entries in ships_data.values():
        for entry in ship_entries:
            stops = entry['stops']
            if not in_denominator(stops):
                continue
            denominator += 1
            if in_numerator(stops):
                numerator += 1
    return ratio(numerator, denominator)

# %% [markdown]
# - For the Carribean, Senegal, Guyana, Louisiana, New France, and France
# - Mascareignes, Madagascar and India
# For each colony in the list above, what were the most common stops prior to these in the other ocean?
#
# - Out of all trips, what % were trips across the 2 oceans?
# - Out of all trips to the Atlantic, what % came from the Indian Ocean? (vice versa)
# - For each Atlantic colony listed above, what # of incoming ships had stopped in the Indian Ocean? (vice versa)

# %% [markdown]
# ### Out of all trips, how many went across both oceans?

# %%
across_oceans = trips_ratio(
    lambda route: has_atlantic(route) and has_indian_ocean(route),       lambda _: True
)
across_oceans_no_met = trips_ratio(
    lambda route: has_atlantic(route, with_metropole=False) and has_indian_ocean(route),       
    lambda _: True
)

print(f"Trips across oceans: {across_oceans}")    
print(f"Excluding the metropole: {across_oceans_no_met}")
# Out:
# Trips across oceans: 814/2158 (38%)
# Excluding the metropole: 383/2158 (18%)

# %% [markdown]
# ### Out of all trips to the Atlantic, what % came from the Indian Ocean? (and vice versa)

# %%
atlantic_to_indian = trips_ratio(
    lambda r: has_atlantic_before_indian(r),
    lambda r: has_indian_ocean(r)
)
indian_to_atlantic = trips_ratio(
    # TODO: "before" is not the right thing to count here
    # because most trips start from the Atlantic, and can do 
    # Atlantic -> Indian -> Atlantic ; how to deal with those?
    lambda r: has_indian_before_atlantic(r),
    lambda r: has_atlantic(r)
)
print(f"Trips to Indian Ocean that passed through the Atlantic: {atlantic_to_indian}")
print(f"Trips to Atlantic that passed through the Indian Ocean: {indian_to_atlantic}")
# Out:
# Trips to Indian Ocean that passed through the Atlantic: 274/945 (29%)
# Trips to Atlantic that passed through the Indian Ocean: 56/1936 (3%)

# %% [markdown]
# ### What were the most likely Atlantic stops before reaching the Indian Ocean?

# %%
# TODO
def most_common_stops(in_atlantic):
    stops_counter = Counter()
    n_trips = 0
    to_add = ATLANTIC_STOPS if in_atlantic else INDIAN_OCEAN_STOPS
    to_stop = INDIAN_OCEAN_STOPS if in_atlantic else ATLANTIC_STOPS
    for ship_entries in ships_data.values():
        for entry in ship_entries:
            # TODO is that the right filter?
            if in_atlantic:
                if not has_atlantic_before_indian(entry['stops']):
                    continue
            else:
                if not has_indian_before_atlantic(entry['stops']):
                    continue
            n_trips += 1
            valid_stops = set()
            
            for stop in entry['stops']:
                if stop in to_add:
                    valid_stops.add(stop)
                if stop in to_stop:
                    break
                    
            for stp in valid_stops:
                stops_counter[stp] +=1

    first = "Atlantic" if in_atlantic else "Indian Ocean"
    second = "Indian Ocean" if in_atlantic else "Atlantic"
    print(f"Most common {first} stops before {second}")
    for stop, cnt in stops_counter.most_common(10):
        print(f"{stop} - {ratio(cnt, n_trips)}")

most_common_stops(True)
print('============================')
most_common_stops(False)
# Out:
# Most common Atlantic stops before Indian Ocean
# Lorient - 238/274 (87%)
# Cadix - 83/274 (30%)
# Gorée - 49/274 (18%)
# Brésil - 35/274 (13%)
# Ascension - 35/274 (13%)
# Cap-Vert - 31/274 (11%)
# Ténériffe - 25/274 (9%)
# Martinique - 16/274 (6%)
# Sénégal et Gorée - 14/274 (5%)
# Santiago - 12/274 (4%)
# ============================
# Most common Indian Ocean stops before Atlantic
# Port-Louis - 38/56 (68%)
# île de France - 11/56 (20%)
# île Bourbon - 5/56 (9%)
# Chandernagor - 3/56 (5%)
# Manille - 2/56 (4%)
# Inde - 2/56 (4%)
# Mascareignes - 2/56 (4%)
# Île de France - 2/56 (4%)
# Pondichéry - 1/56 (2%)
# Batavia - 1/56 (2%)

# %% [markdown]
# ## Below this is work in progress

# %%
def map_stop(stp):
    if is_valid_stop(stp, INDIAN_OCEAN_STOPS):
        return "I"
    if is_valid_stop(stp, ATLANTIC_STOPS):
        return "A"
    return "?"

unknown = Counter()

for ship_entries in ships_data.values():
    for entry in ship_entries:
        for stp in entry['stops']:
            if map_stop(stp) == '?':
                unknown[stp] += 1
#         stops = ''.join([map_stop(s) for s in entry['stops']])
#         print(stops)

unknown.most_common(50)
# Out:
# [('Cap de Bonne-Espérance', 114),
#  ('Chine', 106),
#  ('?', 89),
#  ('vaisseau de côte', 44),
#  ('service des fermes', 37),
#  ('cabotage', 30),
#  ('Hambourg', 14),
#  ('course ?', 12),
#  ('petit cabotage ?', 11),
#  ('petit cabotage', 10),
#  ('Vannes', 10),
#  ('Prise espagnole capturée à Pensacola', 7),
#  ('au devant des vaisseaux', 7),
#  ('aux ordres du roi', 6),
#  ('cabotage ?', 6),
#  ('grand cabotage', 5),
#  ('Chine ?', 4),
#  ('Expédition d’Estaing', 4),
#  ('Le Passage', 4),
#  ('France', 3),
#  ('cap de Bonne-Espérance', 3),
#  ('escadre d’Anville', 3),
#  ('Cabotage', 3),
#  ('course', 3),
#  ('Espagne', 3),
#  ('Canada', 3),
#  ('Île Bourbon', 3),
#  ('cap de Bonne-Espérance ?', 3),
#  ('False Bay', 2),
#  ("En service dans l'Océan Indien", 2),
#  ('grand cabotage ?', 2),
#  ('Amsterdam', 2),
#  ('Prise écossaise capturée par le ', 2),
#  ('pêche ?', 2),
#  ('Terres Australes', 2),
#  ('Tabago (Tobago)', 2),
#  ('Prise anglaise', 2),
#  ('Belle-île', 2),
#  ('côte de Coromandel', 2),
#  ('Mascareigne', 2),
#  ('Île de Ré', 2),
#  ('Martin Vas', 2),
#  ('Falmouth', 2),
#  ('Sierra Leone', 2),
#  ('Quimper', 2),
#  ('Armement à confirmer', 2),
#  ('Les Cayes Saint-Louis ?', 2),
#  ('Canton', 2),
#  ('Prise anglaise capturée à\xa0?', 2),
#  ('pêche en mer du sud ?', 2)]

# %%
# What are the most common stops before Atlantic Ocean stops?

valid_keys = ATLANTIC_KEYS
valid_stops = []
for key in valid_keys:
    valid_stops += LOCATIONS[key]

def is_valid_stop(stop):
    for s in valid_stops:
        if s in stop:
            return True
    return False

def trim_route(route):
    match_idx = -1
    for i, stop in enumerate(route):
        if is_valid_stop(stop):
            match_idx = i
    if match_idx < 0:
        return None
    return route[:match_idx]

n_valid_routes = 0
n_routes = 0
stop_counter = Counter()
for ship_entries in ships_data.values():
    for entry in ship_entries:
        n_routes += 1
        route = trim_route(entry['stops'])
        if route is None:
            continue
        n_valid_routes += 1
        for stop in route:
            stop_counter[stop] +=1

print(f"Number of routes including Atlantic Ocean stops: {n_valid_routes}/{n_routes}")
for stop, cnt in stop_counter.most_common(500):
    print(f"{stop} - {cnt} ({round(cnt/n_stops_total*100)}%)")
# Out:
# Number of routes including Atlantic Ocean stops: 1924/2158
# Lorient - 1132 (16%)
# Inde et Mascareignes - 180 (3%)
# Mascareignes - 177 (3%)
# Saint-Domingue - 142 (2%)
# Cap de Bonne-Espérance - 109 (2%)
# Ascension - 104 (2%)
# Chine - 100 (1%)
# Sénégal et Gorée - 97 (1%)
# Cadix - 93 (1%)
# Sénégal - 90 (1%)
# Le Havre - 84 (1%)
# Louisiane - 82 (1%)
# Nantes - 69 (1%)
# Bordeaux - 67 (1%)
# Saint-Malo - 63 (1%)
# Inde - 61 (1%)
# Martinique - 60 (1%)
# La Rochelle - 56 (1%)
# Gorée - 53 (1%)
# Brest - 47 (1%)
# Marseille - 47 (1%)
# Antilles - 46 (1%)
# Port-Louis - 38 (1%)
# île de France - 37 (1%)
# Anjouan - 34 (0%)
# Rochefort - 31 (0%)
# Cap-Vert - 29 (0%)
# Ténériffe - 28 (0%)
# cabotage - 28 (0%)
# Sainte-Hélène - 26 (0%)
# ? - 25 (0%)
# Sète - 25 (0%)
# Sainte-Hélène et Ascension - 24 (0%)
# Brésil - 24 (0%)
# service des fermes - 23 (0%)
# Juda et côtes de Guinée - 22 (0%)
# Lisbonne - 18 (0%)
# Cap-Français - 18 (0%)
# Juda - 17 (0%)
# Madagascar et Mascareignes - 16 (0%)
# La Corogne - 15 (0%)
# Madagascar - 14 (0%)
# Angola - 14 (0%)
# Hambourg - 14 (0%)
# Île de France - 13 (0%)
# Arguin - 12 (0%)
# Santiago - 12 (0%)
# Fernando de Noronha - 11 (0%)
# Pondichéry - 11 (0%)
# Bayonne - 11 (0%)
# Mascareignes et Madagascar - 10 (0%)
# petit cabotage - 10 (0%)
# Dunkerque - 10 (0%)
# Inde et Mascareignes, Madagascar - 9 (0%)
# Malaga - 9 (0%)
# Honfleur - 9 (0%)
# Moka - 9 (0%)
# Bengale - 9 (0%)
# Paimboeuf - 8 (0%)
# Vannes - 8 (0%)
# Audierne - 7 (0%)
# Rouen - 7 (0%)
# Saint-Pierre et Miquelon - 7 (0%)
# Nantes/Paimboeuf - 7 (0%)
# Amérique - 7 (0%)
# Alicante - 7 (0%)
# Guinée - 6 (0%)
# Portendick - 6 (0%)
# île Bourbon - 6 (0%)
# Toulon - 6 (0%)
# Cayenne - 6 (0%)
# Baltimore - 6 (0%)
# Terre-Neuve - 6 (0%)
# Concarneau - 6 (0%)
# Madagascar, Inde et Mascareignes - 5 (0%)
# Barcelone - 5 (0%)
# Pérou - 5 (0%)
# Port-au-Prince - 5 (0%)
# Saint-Domingue et Louisiane - 5 (0%)
# Granville - 5 (0%)
# grand cabotage - 5 (0%)
# Guadeloupe - 5 (0%)
# Santiago (Cap-Vert) - 5 (0%)
# Louisbourg - 5 (0%)
# au devant des vaisseaux - 5 (0%)
# Sénégal et Portendick - 4 (0%)
# Mozambique - 4 (0%)
# Roscoff - 4 (0%)
# Madère - 4 (0%)
# Londres - 4 (0%)
# Belle-Île - 4 (0%)
# Açores - 4 (0%)
# Mascareignes et Inde - 4 (0%)
# Canaries - 4 (0%)
# Marseille ? - 3 (0%)
# Morlaix - 3 (0%)
# Douarnenez - 3 (0%)
# Cherbourg - 3 (0%)
# Cabotage - 3 (0%)
# Dieppe - 3 (0%)
# Virginie - 3 (0%)
# Batavia - 3 (0%)
# Chandernagor - 3 (0%)
# Vigo - 3 (0%)
# îles de France et de Bourbon - 3 (0%)
# Espagne - 3 (0%)
# Sumatra - 3 (0%)
# Île Bourbon - 3 (0%)
# False Bay - 2 (0%)
# Paimpol - 2 (0%)
# Côtes de Guinée - 2 (0%)
# Bénodet - 2 (0%)
# France - 2 (0%)
# Marennes - 2 (0%)
# Bordeaux ? - 2 (0%)
# Nantes ? - 2 (0%)
# côte de Guinée - 2 (0%)
# Bourgneuf - 2 (0%)
# Arguin, Sénégal et Gorée - 2 (0%)
# Manille - 2 (0%)
# Pauillac - 2 (0%)
# Arguin, Portendick - 2 (0%)
# Bristol - 2 (0%)
# La Grenade - 2 (0%)
# Ascencion - 2 (0%)
# Nantes/Paimbœuf - 2 (0%)
# Saint-Paul de Luanda (Angola) - 2 (0%)
# Québec - 2 (0%)
# escadre d’Anville - 2 (0%)
# Canada - 2 (0%)
# Inde et Mascareignes, Moka - 2 (0%)
# Sénégal ? - 2 (0%)
# Île de Ré - 2 (0%)
# course - 2 (0%)
# Boston - 2 (0%)
# Falmouth - 2 (0%)
# Antilles ? - 2 (0%)
# Moka, Inde et Mascareignes - 2 (0%)
# Quimper - 2 (0%)
# Canton - 2 (0%)
# Martinique et Cap-Français - 1 (0%)
# Nantes Paimboeuf - 1 (0%)
# Port-Louis Lorient - 1 (0%)
# Nantes/Paimboeuf/Mindin - 1 (0%)
# Mascareignes et Batavia - 1 (0%)
# Inde, Madagascar et Mascareignes - 1 (0%)
# Norvège - 1 (0%)
# Berguen - 1 (0%)
# Salou - 1 (0%)
# Saint-Nazaire - 1 (0%)
# Basse-Terre, Guadeloupe - 1 (0%)
# Philadelphie - 1 (0%)
# Cap de Bonne-Espérance, île de France, Batavia - 1 (0%)
# Hollande - 1 (0%)
# Lorient pour l’Inde - 1 (0%)
# cabotage ? - 1 (0%)
# Mascareignes, Madagascar et Inde - 1 (0%)
# Pont-Labbé - 1 (0%)
# Livourne - 1 (0%)
# Auray - 1 (0%)
# Salo - 1 (0%)
# Vinaros - 1 (0%)
# Amsterdam - 1 (0%)
# Sainte-Hélène et Ascencion - 1 (0%)
# Portendick et Arguin - 1 (0%)
# Malacca - 1 (0%)
# Juda, île du Prince - 1 (0%)
# Mascareignes et Indes - 1 (0%)
# Le Croisic - 1 (0%)
# pêche - 1 (0%)
# Saint-Valery-sur-Somme - 1 (0%)
# Landerneau - 1 (0%)
# vaisseau de côte - 1 (0%)
# Paimbœuf - 1 (0%)
# Sénégal, Gorée et Portendick - 1 (0%)
# Sénégal ? - 1 (0%)
# Sainte-Hélène  - 1 (0%)
# Angola et Guinée - 1 (0%)
# idef - 1 (0%)
# Le Conquet - 1 (0%)
# Rio de Janeiro - 1 (0%)
# Échoué près de Saint-Nazaire et renfloué - 1 (0%)
# Amérique française - 1 (0%)
# côte d’Afrique - 1 (0%)
# île Grande - 1 (0%)
# Baie de Biscay - 1 (0%)
# Sénégal et Arguin - 1 (0%)
# cabotage (Nantes et Saint-Malo) - 1 (0%)
#  Saint-Domingue - 1 (0%)
# Sénégal, Portendick et Gorée - 1 (0%)
# Belle-île - 1 (0%)
# île de Ré - 1 (0%)
#  Chine - 1 (0%)
# Île Royale et  Louisbourg - 1 (0%)
# Louisbourg (Acadie) - 1 (0%)
# Cap-Français (St-Domingue) - 1 (0%)
# Mascareignes et Pondichéry - 1 (0%)
# Cochinchine - 1 (0%)
# journalier de rade - 1 (0%)
# Mahé et côte ouest de l’Inde - 1 (0%)
#  Antilles ? - 1 (0%)
# Saint-Petersbourg - 1 (0%)
# Poulo-Condor - 1 (0%)
# Madagascar et Comores - 1 (0%)
# Deptford - 1 (0%)
# Île Grande - 1 (0%)
# Mascareignes et Seychelles - 1 (0%)
# Birmanie -Inde - 1 (0%)
# Mascareigne - 1 (0%)
# Redon - 1 (0%)
# Brest (?) - 1 (0%)
# Ténérife - 1 (0%)
#  Brésil - 1 (0%)
# la Grenade - 1 (0%)
# St-Domingue - 1 (0%)
# Saint-Domigue - 1 (0%)
# Le Havre ? - 1 (0%)
# Guyane - 1 (0%)
# Le Passage - 1 (0%)
# course dans l’Océan Indien - 1 (0%)
#  ? - 1 (0%)
# Saiint-Domingue - 1 (0%)
# côtes de Guinée et Juda - 1 (0%)
# Juda et île du Prince - 1 (0%)
# Île d'Aix - 1 (0%)
# Île de France et Mozambique - 1 (0%)
# La Rochelle ? - 1 (0%)
# Guinée ou Sénégal - 1 (0%)
# Civita-Vecchia - 1 (0%)
#  au devant des vaisseaux - 1 (0%)
# Équipage parti par voie de terre de Saint-Malo - 1 (0%)
# Nouvelle Écosse - 1 (0%)
# Saint-Pierre (Martinique) - 1 (0%)
# Saint-Domingue et Amérique - 1 (0%)
# Saint-Domingue ? - 1 (0%)
# Edington - 1 (0%)
# Angleterre - 1 (0%)
# Inde et Mascareignes, Siam - 1 (0%)
# Tabago (Tobago) - 1 (0%)
# Java - 1 (0%)
# Lorient Cap-Vert - 1 (0%)
# Quillebeuf - 1 (0%)
# Terres Australes - 1 (0%)
# Pontevedra - 1 (0%)
# Birmanie - 1 (0%)
# Paimboeuf/Nantes - 1 (0%)
# Côte de Guinée - 1 (0%)
#  Portendick, Sénégal et Gorée - 1 (0%)
# Luanda - 1 (0%)
# Petit Goave - 1 (0%)
# Côte occidentale d’Afrique - 1 (0%)
# Gottembourg - 1 (0%)
# Fécamp - 1 (0%)
# Vera Cruz (Mexique) - 1 (0%)
# Sénégal et Gorée, Portendick - 1 (0%)
# Sénégal et Gorée, Portendick  - 1 (0%)
# Santander - 1 (0%)
# Martinique et Guadeloupe - 1 (0%)
# cap de Bonne-Espérance ? - 1 (0%)
# Moka et Mascareignes - 1 (0%)
#  Mascareignes - 1 (0%)
# Mindin - 1 (0%)
# Siam - 1 (0%)
# Portendick, Sénégal et Gorée - 1 (0%)
# Inde et Mascareigne - 1 (0%)
# Pointe-à-Pitre, Guadeloupe - 1 (0%)
# Comores - 1 (0%)
# Lorient- Vannes - 1 (0%)
# Île d’Aix - 1 (0%)
# Martinique et Saint-Domingue - 1 (0%)
# Plymouth - 1 (0%)
# Mascareignes et Madagascar, cap de Bonne-Espérance - 1 (0%)
# lMascareignes - 1 (0%)
# Belle-île-en-Mer - 1 (0%)
# Paimboeuf ? - 1 (0%)
# Philippines - 1 (0%)
# Pondichéry et Bengale - 1 (0%)
# île de France et Inde - 1 (0%)
# Guinée ? - 1 (0%)
# Sète ? - 1 (0%)

# %%
for ship_entries in ships_data.values():
    for entry in ship_entries:
        if any(stop == 'Ascension' for stop in entry['stops']):
            print(' > '.join(entry['stops']))
# Out:
# Lorient > Cadix > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Inde, Madagascar et Mascareignes > Ascension > Lorient
# Lorient > Mascareignes > Cap de Bonne-Espérance > Ascension > Lorient
# Lorient > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Gorée > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Gorée > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Madagascar > Inde et Mascareignes > Ascension > Lorient
# Lorient > Gorée > Cap de Bonne-Espérance > Madagascar et Mascareignes > Ascension > Lorient
# Lorient > Brésil > Mascareignes > Ascension > Lorient
# Lorient > Madagascar > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap-Vert > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Ténériffe > Cap-Vert > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Madagascar > Inde et Mascareignes > Ascension > Lorient
# idef > Manille > Chine > île de France > Ascension > Lorient
# Lorient > Gorée > Cap de Bonne-Espérance > Inde et Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Inde et Mascareignes > Ascension > Lorient
# Lorient > Ténériffe > Sénégal et Gorée > Cap de Bonne-Espérance > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap-Vert > Inde et Mascareignes > Ascension > Vigo > Lorient
# Lorient > Chine > Mascareignes > Ascension > Lorient
# Lorient > La Rochelle > Cadix > Mascareignes > Cap de Bonne-Espérance > Ascension > La Rochelle > Lorient
# Lorient > Bordeaux > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Nantes > Inde et Mascareignes > Ascension > Lorient
# Lorient > Madagascar, Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Ténériffe > Cap de Bonne-Espérance > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Gorée > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap-Vert > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Madagascar et Comores > Inde et Mascareignes > Ascension > Martinique > Lorient
# Lorient > Cadix > Madagascar > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Ténériffe > Sénégal et Gorée > Inde et Mascareignes > Ascension > Lorient
# Lorient > Inde et Mascareignes, Moka > Ascension > Lorient
# Lorient > Gorée > Mascareignes > Ascension > Lorient
# Lorient > Lisbonne > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Gorée > Cap de Bonne-Espérance > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Anjouan > Moka > Mascareignes > Ascension > Lorient
# Lorient > Cap-Vert > Mascareignes > Chine > Mascareignes > Ascension > La Corogne > Lorient
# Lorient > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Chine > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Gorée > Cap de Bonne-Espérance > Inde et Mascareignes > Saint-Paul de Luanda (Angola) > Ascension > Lorient
# Lorient > Cap-Vert > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Anjouan > Inde et Mascareignes > Ascension > Port-Louis > Lorient
# Lorient > Cap de Bonne-Espérance > Chine > Mascareignes > Ascension > Lorient
# Lorient > Sénégal > Ascension > Lorient
# Lorient > Mascareignes > course dans l’Océan Indien > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Inde et Mascareignes > Ascension > Lorient
# Lorient > Inde et Mascareignes > Ascension > Lorient
# Lorient > Santiago > Chine > Mascareignes > Ascension > Lorient
# Lorient > Santiago (Cap-Vert) > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap de Bonne-Espérance > Inde > Ascension > Lorient
# Lorient > Madagascar > Inde et Mascareignes > Ascension > Lorient
# Lorient > Ténériffe > Madagascar, Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap-Vert > Inde et Mascareignes, Moka > Ascension > Lorient
# Lorient > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Madagascar > Inde et Mascareignes > Ascension > Lorient
# Lorient > Inde et Mascareignes > Ascension > Lorient
# Lorient > Chine > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Inde et Mascareignes > Cap de Bonne-Espérance > Ascension > Lorient
# Lorient > Cadix > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Falmouth > Santiago > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap de Bonne-Espérance > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Gorée > Inde et Mascareignes > Ascension > Lorient
# Lorient > Mascareignes > Ascension > Lorient
# Lorient > Gorée > Cap de Bonne-Espérance > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap de Bonne-Espérance > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Ténériffe > Anjouan > Moka > Mascareignes > Ascension > Lorient
# Lorient > Cap-Vert > Mascareignes > Chine > Mascareignes > Ascension > Louisbourg > Lorient
# Lorient > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Mascareignes > Ascension > Lorient
# Rochefort > Chine > Sainte-Hélène > Ascension > Lorient
# Lorient > Juda et côtes de Guinée > Madagascar et Mascareignes > Ascension > Lorient
# Lorient > Chine > Ascension > Lorient
# Lorient > Santiago > Chine > Mascareignes > Ascension > Lorient
# Lorient > Gorée > Mascareignes > Ascension > Lorient
# Lorient > Santiago > Inde et Mascareignes > Ascension > Lorient
# Lorient > Ténériffe > Inde et Mascareignes, Madagascar > Ascension > Martinique > Lorient
# Lorient > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Santiago > Anjouan > Inde et Mascareignes > Ascension > Louisbourg > Lorient
# Lorient > Cadix > Cap de Bonne-Espérance > Inde et Mascareignes, Madagascar > Ascension > Lorient
# Lorient > Cadix > Madagascar > Inde et Mascareignes > Ascension > Lorient
# Lorient > Madagascar > Inde et Mascareignes > Ascension > Lorient
# Lorient > Chine > Mascareignes > Ascension > Louisbourg > Lorient
# Lorient > Gorée > Cap de Bonne-Espérance > Inde et Mascareignes > Ascension > Lorient
# Lorient > Santiago > Inde et Mascareignes > Ascension > Lorient
# Lorient > Santiago (Cap-Vert) > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Cap-Vert > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap de Bonne-Espérance > Chine > Mascareignes > Ascension > Lorient
# Lorient > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Madagascar > Moka > Mascareignes > Ascension > Lorient
# Lorient > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cap-Vert > Mascareignes > Comores > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Anjouan > Inde et Mascareignes > Ascension > Lorient
# Lorient > Gorée > Inde et Mascareignes > Ascension > Lorient
# Saint-Malo > Plymouth > Chine > Inde et Mascareignes > Ascension > Lorient
# Lorient > Santiago > Inde et Mascareignes > Ascension > Lorient
# Lorient > Gorée > Inde et Mascareignes > Ascension > Lorient
# Lorient > Ténériffe > Sénégal et Gorée > Inde et Mascareignes > Ascension > Lorient
# Lorient > Cadix > Mascareignes > Chine > Mascareignes > Ascension > Lorient
# Lorient > Cadix > Chine > Mascareignes > Ascension > Lorient

# %%
indian_ocean_routes
# Out:
# ine > Mascareignes > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > île de France > Chine > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Inde > Chine > Inde > Cap de Bonne-Espérance > Lorient',
#  'Port-Louis > Louisiane > Saint-Domingue > Rochefort',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Chine > Mascareignes > Saint-Paul de Luanda (Angola) > Lorient',
#  'Lorient > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Cadix > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Cadix > Inde > Chine > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Madagascar et Mascareignes > Inde > Mascareignes > Lorient',
#  'Lorient > Inde > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Île de France > Mozambique > Cap de Bonne-Espérance > Saint-Domingue > Nantes',
#  'Rochefort > Mascareignes > Inde > Mascareignes > Lorient',
#  'Lorient > La Rochelle > Cadix > Mascareignes > Cap de Bonne-Espérance > Ascension > La Rochelle > Lorient',
#  'La Rochelle > Mascareignes > Chine > île de France > Lorient',
#  'Lorient > Mascareignes > Inde > Mascareignes > Lorient',
#  'Brest > Rochefort > La Corogne > Port-Louis',
#  'Marseille > îles de France et de Bourbon > Lorient',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Bordeaux > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Cap-Vert > Brésil > Mascareignes > Inde > vaisseau de côte',
#  'Lorient > Inde et Mascareignes > Madagascar > Le Passage',
#  'Lorient > Pondichéry > Mahé et côte ouest de l’Inde > Chine > Lorient',
#  'Lorient > Inde > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Mascareignes',
#  'Saint-Malo > Brest > Port-Louis',
#  'Port-Louis > Louisiane > Lorient',
#  'Lorient > Inde > Nantes',
#  'Le Havre > Cadix > Île de France > Moka > Pondichéry > Île de France > Lorient',
#  'Confisqué à Saint-Paul île Bourbon > Mascareignes > vaisseau de côte',
#  'Nantes > Paimboeuf > Port-Louis',
#  'Port-Louis > Bordeaux ?',
#  'Angleterre > côte de Coromandel > Bengale',
#  'Lorient > Sénégal > Mascareignes',
#  'Pondichéry > Mascareignes > Pondichéry',
#  'Lorient > Cadix > Ténériffe > Cap de Bonne-Espérance > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Île de France > Inde',
#  'Lorient > Cap de Bonne-Espérance > Inde > Chine',
#  'Lorient > Mascareignes > Poulo-Condor > Chine > Mascareignes > Lorient',
#  'Lorient > Cadix > Madagascar > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Chine > Mascareignes > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Cadix > Mascareignes > Inde',
#  'Saint-Malo > Inde > Port-Louis',
#  'Lorient > Ténériffe > île de France > Lorient',
#  'Saint-Malo > Terre-Neuve > Marseille > Port-Louis',
#  'Lorient > Cap-Vert > Mascareignes > Anjouan > Inde > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Gorée > Anjouan > Inde et Mascareignes > Brésil > Lorient',
#  'Lorient > Mascareignes et Seychelles > Inde > Birmanie -Inde > Mascareigne > Lorient',
#  'Lorient > île de France > Cap de Bonne-Espérance > Port-Louis > Nantes',
#  'Lorient > îles de France et de Bourbon',
#  'Île de France > France',
#  'Port-Louis > Louisiane',
#  'Port-Louis > Louisiane',
#  'Lorient > Mascareignes > La Corogne',
#  'Lorient > Mascareignes',
#  'Lorient > Inde > Lorient',
#  'Port-Louis > Bordeaux > Amérique ?',
#  'Bordeaux > cabotage > Port-Louis',
#  'Port-Louis > Nantes ?',
#  'Lorient > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Brésil > Sumatra > Chine > Mascareignes > Lorient',
#  'Lorient > Gorée > Mascareignes > Ascension > Lorient',
#  'Lorient > Cadix > Anjouan > Moka > Mascareignes > Ascension > Lorient',
#  'Lorient > Chine > Mascareignes > Lorient',
#  'Lorient > Cap-Vert > Mascareignes > Chine > Mascareignes > Ascension > La Corogne > Lorient',
#  'Lorient > Mascareignes > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Cadix > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Juda > cap de Bonne-Espérance > Mascareignes',
#  'Lorient > Mascareignes > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Cadix > Mascareignes > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Inde > Chine > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Cadix > île de France > Chine > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Inde > Cap de Bonne-Espérance > Lorient',
#  'Saint-Malo > Île de France > Chine > Cap de Bonne-Espérance > Lorient',
#  'Chandernagor > Mascareignes > Lorient',
#  'Lorient > île de France > Bengale > île de France > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Inde',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Inde > Chine > île de France > Lorient',
#  'Lorient > Madagascar > Bengale > Mascareignes > Lorient',
#  'Lorient > Cadix > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Gorée > Mascareignes > vaisseau de côte',
#  'île de France > île Bourbon > Cap de Bonne-Espérance > Lorient',
#  'Lorient > ? > Chandernagor',
#  'Lorient > Inde et Mascareignes > Madagascar > Lisbonne',
#  'Bordeaux > Gorée > Mascareignes > Angola > St-Domingue > Bordeaux',
#  'Dunkerque > Louisiane > Martinique (?) > Port-Louis',
#  'Lorient > Cadix > Madagascar > Inde et Mascareignes > Lorient',
#  'Lorient > Anjouan > Inde et Mascareignes > Ascension > Port-Louis > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Louisiane > Saint-Domingue > Port-Louis',
#  'La Rochelle > Mascareignes > Antilles > La Rochelle\xa0?',
#  'Brest > Port-Louis',
#  'Port-Louis > Louisiane',
#  'Lorient > Ténériffe > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Inde',
#  'Lorient > île de France > Inde',
#  'île de France > île Bourbon > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Cap de Bonne-Espérance > Lorient',
#  'Lorient > île de France > Lorient',
#  'Lorient > Inde',
#  'Lorient > Sénégal et Gorée > Mascareignes > Lorient',
#  'Lorient > Sénégal > Mascareignes > La Corogne > Le Passage > Lorient',
#  'Lorient > Inde et Mascareignes > Pondichéry > Philippines > Inde',
#  'Lorient > Inde et Mascareignes > Pondichéry > Philippines > Inde',
#  'Port-Louis > La Rochelle ?',
#  'Lorient > Inde > Lorient',
#  'Lorient > île de France > Cap de Bonne-Espérance > Antilles > Nantes > Lorient',
#  'Lorient > Mascareignes > course dans l’Océan Indien > Mascareignes > Ascension > Lorient',
#  'Bordeaux > Martinique > Port-Louis',
#  'Rochefort > Ténériffe > Cap de Bonne-Espérance > Mascareignes > Lorient',
#  'Lorient > Gorée > Mascareignes > ?',
#  'Lorient > Gorée > Mascareignes > vaisseau de côte',
#  'Port-Louis > Québec ?',
#  'Lorient > Santiago > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Mascareignes',
#  'Saint-Malo > Brest > Québec > La Rochelle > Port-Louis',
#  'Chandernagor > Mascareignes > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Inde > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Cap-Vert > Mascareignes > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Inde > Ascension > Lorient',
#  'Lorient > Madagascar > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Mascareigne > Inde > vaisseau de côte',
#  'Lorient > Gorée > Mascareignes > Canada',
#  'Pondichéry > Mascareignes et Madagascar > Pondichéry',
#  'Pondichéry > Mascareignes et Madagascar > Pondichéry',
#  'Bordeaux > Brest > Mascareignes > Inde > Cap de Bonne-Espérance > La Corogne > Lorient',
#  'Brest > Lorient > Santiago (Cap-Vert) > Cap de Bonne-Espérance > Mascareignes > Inde > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Gorée > Chine > Mascareignes > Lorient',
#  'Lorient > Le Havre > Port-Louis',
#  'Bordeaux > Martinique > Saint-Domingue > Port-Louis',
#  'île de France > Lorient',
#  'Saint-Malo > Terre-Neuve > Belle-île > Port-Louis',
#  'Lorient > Cadix > Cap-Vert > Anjouan > Inde et Mascareignes > Antilles > Lorient',
#  'Lorient > Cadix > Madagascar > Inde et Mascareignes > Ascension > Lorient',
#  'Marseille > Carthagène > Malaga > Cadix > Port-Louis',
#  'Le Havre > Martinique > Port-Louis',
#  'Saint-Malo > Bordeaux > Mascareignes > Cap de Bonne-Espérance > Lorient',
#  'Pondichéry > ?',
#  'Port-Louis > Louisiane > Lorient',
#  'Lorient > Rio de Janeiro > Mascareignes > vaisseau de côte',
#  'Lorient > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Chine > Mascareignes > Ascension > Lorient',
#  'Port-Louis > Cadix ?',
#  'Lorient > île de France',
#  'Port-Louis > Bordeaux > Saint-Domingue ?',
#  'Lorient > Cadix > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Dieppe > Lorient > Mascareignes > vaisseau de côte',
#  'Lorient > Inde',
#  'Lorient > Cap de Bonne-Espérance > Mascareignes > Chine > Mascareignes > Espagne > Lorient',
#  'Lorient > Santiago > Cap de Bonne-Espérance > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Gorée > Inde et Mascareignes > Chine > Mascareignes > Angola > Lorient',
#  'île de France > Madagascar > Inde > Île de France',
#  'Brest > Port-Louis',
#  'Lorient > Mascareignes > Ascension > Lorient',
#  'Lorient > ? > Île de France',
#  'Lorient > Gorée > Madagascar > Inde et Mascareignes > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Anjouan > Inde > Madagascar et Mascareignes',
#  'Lorient > Inde > Lorient',
#  'Lorient > Cadix > Inde > Cap de Bonne-Espérance > Sierra Leone',
#  'Lorient > Mascareignes > Chine > ? > Lorient',
#  'Lorient > Cadix > Pondichéry > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Pondichéry > Lorient',
#  'Saint-Malo > Brest > Port-Louis',
#  'Lorient > Pondichéry > Lorient',
#  'Lorient Cap-Vert > Mascareignes > Chine > Inde et Mascareignes > Fernando de Noronha > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Mascareignes > Chine > Mascareignes > Ascension > Lorient',
#  'Port-Louis > Sète ?',
#  'Marseille > Mascareignes > Cap de Bonne-Espérance > Mascareignes et Inde > Lorient',
#  'Nantes/Paimboeuf > Marseille > Port-Louis',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Cadix > Anjouan > Inde et Mascareignes > Lorient',
#  'Lorient > Mascareignes > Inde > Lorient',
#  'Lorient > Mascareignes > Inde > Birmanie > Inde > Mascareignes > Lorient',
#  'Saint-Malo > Saint-Domingue > Port-Louis',
#  'Bordeaux > Cap-Français > Port-Louis',
#  'Lorient > Cadix > Ténériffe > Île de France > Chine > Sainte-Hélène > Lorient',
#  'Lorient > Ténériffe > Anjouan > Moka > Mascareignes > Ascension > Lorient',
#  'Lorient > Chine > Mascareignes > Lorient',
#  'Lorient > Cap-Vert > Mascareignes > Chine > Mascareignes > Ascension > Louisbourg > Lorient',
#  'Lorient > Mascareignes > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Île de France',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Batavia > Mascareignes > Cap de Bonne-Espérance > Mascareignes > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Mascareignes > Ascension > Lorient',
#  'Lorient > Cadix > Mascareignes > Chine > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Cadix > Madagascar > Inde et Mascareignes > Louisbourg > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Chine > Mascareignes > Sainte-Hélène et Ascension > Lorient',
#  'Nantes > Lorient > Mascareignes > Lorient',
#  'Lorient > Inde > Bengale',
#  'Lorient > Mascareignes',
#  'Saint-Malo > Brest > Port-Louis',
#  'Lorient > Cadix > Inde > Chine > Inde',
#  'Lorient > Bengale > Sainte-Hélène > Lorient',
#  'Le Havre > Port-Louis > Saint-Domingue > Louisiane > Lorient',
#  'Port-Louis > Louisiane > Lorient',
#  'Lorient > Brésil > Mascareignes',
#  'Lorient > Pondichéry > Lorient',
#  'Lorient > Inde > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Bengale > Lorient',
#  'Lorient > Mascareignes > Lorient',
#  'île de France > Lorient',
#  'Port-Louis > course ?',
#  'Lorient > Inde',
#  'Lorient > Ténériffe > Cap-Vert > Madagascar et Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Santiago > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Mascareignes > Inde > Chine > Luanda > Lorient',
#  'Lorient > île de France > Foulpointe, Madagascar',
#  'Cap-Français > Nantes > Port-Louis',
#  'Port-Louis > Cap-Français ?',
#  'Port-Louis > Cap-Français > Port-Louis',
#  'Petit Goave > côte de Saint-Domingue > Port-Louis',
#  'Port-Louis > Les Cayes Saint-Louis ?',
#  'Port-Louis > Bordeaux ?',
#  'Le Havre > Inde > Lorient',
#  'Île de France > Île Bourbon > Cap de Bonne-Espérance > Lorient',
#  'Lorient > île de France',
#  'Lorient > Inde > Lorient',
#  'Lorient > Inde',
#  'Lorient > Brésil > Mascareignes > cap de Bonne-Espérance > Mascareignes >  vaisseau de côte',
#  'Lorient > Mascareignes',
#  'Port-Louis > Louisiane > Port-Louis',
#  'Lorient > Cadix > Anjouan > Inde et Mascareignes > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Gorée > Mascareignes',
#  'Saint-Malo > îles de France et de Bourbon > Lorient',
#  'Marseille > Cadix > Cap-Français > Vera Cruz (Mexique) > Cap-Français > Port-Louis',
#  'Pondichéry > Mascareignes > Pondichéry',
#  'Pondichéry > Mascareignes > Pondichéry',
#  'Saint-Malo > Inde',
#  'Pondichéry > Bengale > Pondichéry > Bengale > Pondichéry',
#  'Lorient > Mascareignes et Madagascar > Inde',
#  'Lorient > Inde et Mascareignes > île de France > vaisseau de côte',
#  'Lorient > Gorée > Mascareignes > Ascension > Lorient',
#  'Pondichéry > Mascareignes > Pondichéry',
#  'Pondichéry > Mascareignes > Pondichéry',
#  'Pondichéry > Mascareignes > Pondichéry',
#  'Lorient > Gorée > Mascareignes > Anjouan > Inde et Mascareignes > Açores > Lorient',
#  'Lorient > Brésil > Mascareignes > Inde > Chine > Mascareignes et Madagascar > Santander > Rochefort',
#  'Rochefort > Mascareignes',
#  'Lorient > Mascareignes > Lorient',
#  'Marseille > Saint-Domingue > Bordeaux > Vannes > Port-Louis',
#  'Le Havre > Cadix > Marseille > Port-Louis',
#  'Lorient > Lisbonne > Brésil > Mascareignes > Lorient',
#  'Port-Louis > course ?',
#  'Port-Louis > Buenos-Ayres > Lisbonne',
#  'Lorient > Mascareignes et Madagascar > Inde > Mascareignes > Cap de Bonne-Espérance > Lorient',
#  'Lorient > Inde > île Bourbon > Lorient',
#  'Lorient > ? > Chine > île de France > Lorient',
#  'Lorient > cap de Bonne-Espérance ? > Mascareignes > Bordeaux',
#  'Bordeaux > île de France',
#  'Lorient > Anjouan > Inde et Mascareignes, Madagascar > La Corogne > Lorient',
#  'Lorient > Rio de Janeiro > Cap de Bonne-Espérance > Mascareignes',
#  'La Rochelle > Mascareignes > Cap de Bonne-Espérance > Mascareignes > Inde > Lorient',
#  'Port-Louis > La Rochelle ?',
#  'Lorient > Chine > Mascareignes > Lorient',
#  'Lorient > Île de France > Canton > Île de France > Lorient',
#  'Lorient > Mascareignes > Inde > Chine > Cap de Bonne-Espérance > Sainte-Hélène > Lorient',
#  'Lorient > Mascareignes et Inde > Chine > Mascareignes > Vigo > La Corogne > Lorient',
#  'Lorient > Cadix > Anjouan > Inde et Mascareignes > Lorient',
#  'Lorient > Ténériffe > Anjouan > Inde et Mascareignes, Madagascar > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Mascareignes > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Brest > Lorient > Port-Louis > Lorient > Sénégal',
#  'Lorient > Mascareignes',
#  'Lorient > Santiago (Cap-Vert) > Chine > Mascareignes > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Santiago > Anjouan > Inde et Mascareignes > Ascension > Louisbourg > Lorient',
#  'Lorient > Cadix > Chine > Mascareignes > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Inde > Chine > Mascareignes > Lorient',
#  'Lorient > Cadix > Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Cadix > Mascareignes > Ascencion > Lorient',
#  'Lorient > Mascareignes > Chine > Lorient',
#  'Lorient > Cadix > Madagascar > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Madagascar > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Inde',
#  'Lorient > Chine > Mascareignes > Ascension > Louisbourg > Lorient',
#  'Lorient > Chine > Mascareignes > Antilles > Lorient',
#  'Lorient > Santiago (Cap-Vert) > Mascareignes > Ascension > Lorient',
#  'Le Havre > Martinique > Port-Louis',
#  'Saint-Malo > Chine > La Corogne > Port-Louis',
#  'Lorient > Cadix > Cap-Vert > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Chine > Mascareignes > Ascension > Lorient',
#  'Madras > Inde et Mascareignes > vaisseau de côte',
#  'Lorient > Inde et Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > Gorée > Cap de Bonne-Espérance > Inde et Mascareignes > Chine > Mascareignes > Lorient',
#  'Lorient > îles de France et de Bourbon > Lorient',
#  'Brest > Cadix > Moka > Mascareignes > Lorient',
#  'Lorient > Cadix > Madagascar > Moka > Mascareignes > Ascension > Lorient',
#  'Lorient > Cadix > Chine > Île de France > Lorient',
#  'Rochefort > Saint-Pierre et Miquelon > Port-Louis',
#  'Bordeaux > Martinique > Port-Louis',
#  'Port-Louis > Bordeaux ?',
#  'Nantes/Paimboeuf > Lorient > île de France > Lorient',
#  'Lorient > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Inde > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Cap-Vert > Mascareignes > Comores > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Cadix > Île de France > Inde > Chine > Lorient',
#  'Port-Louis > Bordeaux ?',
#  'Lorient > Île Grande (Brésil) > Mascareignes',
#  'Lorient > Sénégal et Gorée > Mascareignes > vaisseau de côte',
#  'Lorient- Vannes > Bordeaux > Rochefort > Île d’Aix > Brest > Port-Louis',
#  'Portsmouth > côte de Coromandel > Bengale',
#  'Bordeaux > Martinique > Port-Louis',
#  'Port-Louis > Bordeaux > îles françaises de l’Amérique ?',
#  'Saint-Malo > Brest > Port-Louis',
#  'Port-Louis > Terre-Neuve ?',
#  'Saint-Malo > Mascareignes > Inde > Cap de Bonne-Espérance > Saint-Malo > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Inde > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Inde > Lorient',
#  'Lorient > Cadix > Anjouan > Inde et Mascareignes > Ascension > Lorient',
#  'Lorient > Sénégal > Port-Louis',
#  'Saint-Malo > Cadix > Mascareignes > Moka > Mascareignes > Lorient',
#  'Lorient > Santiago > Anjouan > Inde et Mascareignes > Sainte-Hélène > Lorient',
#  'Lorient > Inde > Chandernagor',
#  'Port-Louis > Bordeaux ?',
#  'Lorient > La Rochelle > lMascareignes > Inde > Mascareignes > Lorient',
#  'Lorient > île de France > Inde > Chine > île de France > Lorient',
#  'île de France > île Bourbon > Inde > île de France > Lorient',
#  'Lorient > Anjouan > Inde > Chine > Sainte-Hélène > Lorient',
#  'Lorient > Alicante > Sète > Malaga > Port-Louis > Nantes/Paimboeuf > Alicante > Marseille > Malaga > Lorient',
#  'Saint-Malo > Lorient > Philippines > Inde > Mascareignes > Lorient',
#  'Île de France > Lorient',
#  'Lorient > Inde et Mascareignes > Île de France > vaisseau de côte',
#  'Lorient > Île de France',
#  'Lorient > Mascareignes',
#  'Nantes > Moka > Inde > Lorient',
#  'Lorient > Port-Louis > Bordeaux > Marseille > Lorient',
#  'Lorient > île de France',
#  'Bordeaux > Mascareignes',
#  'Lorient > Cadix > Mascareignes > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Chine > Mascareignes > Lorient',
#  'Lorient > Cadix > Cap de Bonne-Espérance > Inde > Cap de Bonne-Espérance > La Corogne > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Chine > Mascareignes > Sainte-Hélène et Ascension > Lorient',
#  'Lorient > Cap de Bonne-Espérance > Inde > Chine > Mascareignes > vaisseau de côte',
#  'Lorient > Ténériffe > côte du sud-ouest africain > Sainte-Hélène > Mascareignes',
#  'Lorient > Mascareignes > Lorient',
#  'Île de France > vaisseau de côte, voyage de découverte dans l’Océan Indien',
#  'Lorient > île de France > Inde ?',
#  'Port-Louis > Saint-Domingue > Louisiane > Lorient',
#  'Lorient > Inde > Chine > Mascareignes > La Corogne > Lorient',
#  'Lorient > Mascareignes > Lorient',
#  'Lorient > Cadix > Chine > Mascareignes > Ascension > Lorient',
#  'Lorient > Cadix > Mascareignes > Inde > vaisseau de côte',
#  'Lorient > Ténériffe > Île de France > Cap de Bonne-Espérance > Lorient',
#  'Lorient > île de France > ?',
#  'Pondichéry > armé pour les Mascareignes']

# %%
LOCATIONS = {
    'Isle Bourbon & Isle of France': ['Mascareignes', 'îles de France et de Bourbon', 'île Bourbon', 'Port-Louis, île de France', 'île de France', 'Île de France'] ,
    'Senegal': ['Sénégal', 'Sénégal et Gorée', 'Gorée', 'Cap-Vert', 'Juda et côtes de Guinée', 'Juda'],
    'Caribbean': ['Saint-Domingue', 'Martinique', 'Antilles', 'Cap-Français', 'Saint-Louis, St-Domingue', 'Léogane', 'Port-au-Prince', 'La Grenade (île de)', 'Petit-Goâve, St-Domingue', 'Guadeloupe'],
    'Louisiana': ['Louisiane', 'Ascension', 'Nouvelle-Orléans', 'Biloxy, Louisiane'],
    'France': ['Le Havre', 'Nantes', 'Bordeaux', 'Saint-Malo', 'Brest', 'La Rochelle', 'Marseille', 'Rochefort', 'Sète', 'Bayonne', 'Honfleur', 'Dunkerque', 'Rouen', 'Groix', 'Lorient', 'Toulon', 'Paimboeuf', 'Belle-île-en-Mer'],
    'Madagascar': ['Madagascar', 'Port-Louis', 'Anjouan', 'Fort-Dauphin, Madagascar', 'Sainte-Marie, Madagascar', 'baie de St-Augustin, Madagsascar'],  # TODO
    'India': ['Inde', 'Karaikal', 'Karikal', 'Pondichéry', 'Bengale', 'Calicut', 'Goa', 'Chandernagor', 'Négapatam', 'Madras', 'sur le Gange'],
    'New France': ['Louisbourg (île Royale), Canada', 'Saint-Pierre et Miquelon', 'Terre-Neuve'],
    'Guyana': ['Guyane', 'Cayenne'],
    'Brazil': ['Brésil'],
    'Cape of Good Hope': ['Cap de Bonne-Espérance'],
}

# %%
def normalize_location(location):
    matches = []
    # in cases like "Mascareignes et Madagascar", we want to
    # retain both 'Mascareignes' (Bourbon) and 'Madagascar' as separate stops
    # That's why we return a list as opposed to a single name.
    for key, synonyms in LOCATIONS.items():
        for synonym in synonyms:
            if synonym in location:
                matches.append((key, synonym))
                break
    # If >1 stop, return stops in their order of appearance in the input
    # eg "Inde et Mascareignes" => ['India', 'Bourbon']
    # but "Mascareignes et Madagascar" => ['Bourbon', 'Madagascar']
    res = [m[0] for m in sorted(matches, key=lambda m: location.index(m[1]))]
    return res

def normalize_itinerary(itinerary):
    # normalize locations, skip unknown locations, no contiguous duplicates
    result = []
    for stop in itinerary:
        next_stops = normalize_location(stop)
        # TODO is that right?
        next_stops = next_stops if len(next_stops) > 0 else [stop]
        if len(result) == 0 or len(result) > 0 and all(s != result[-1] for s in next_stops):
            result += next_stops
    return result # result if len(result) > 1 else []

# %%
routes_counter = Counter()
unnormalized_routes = set()
n_routes = 0
n_empty = 0

for k, v in ships_data.items():
    for entry in v:
        n_routes += 1
        stops_v1 = normalize_itinerary(entry['stops'])
        ship_log = [e['location'] for e in entry['ship_log']]
        if len(ship_log) == 0:
            n_empty += 1
        stops_v2 = normalize_itinerary(ship_log)
        unnormalized_routes.add(' > '.join(entry['stops']))

        # use the itinerary with the most detail out of the two
        # stops = stops_v1 if len(stops_v1) > len(stops_v2) else stops_v2
        stops = stops_v1
        route = ' > '.join(stops)
        routes_counter[route] += 1

print(f"Empty routes: {n_empty}")
n_normalized_routes = len(routes_counter)
print(f"Total routes: {n_routes}")
print(f"Distinct routes (unnormalized): {len(unnormalized_routes)}")
print(f"Distint routes (normalized): {n_normalized_routes}")
most_common = routes_counter.most_common(100)
for r, cnt in most_common:
    print(f"{r} - {cnt} ({round(cnt/n_routes*100, 0)}%)")
# Out:
# Empty routes: 200
# Total routes: 2158
# Distinct routes (unnormalized): 1206
# Distint routes (normalized): 691
# France - 207 (10.0%)
# France > Senegal > Caribbean > France - 86 (4.0%)
# India - 85 (4.0%)
# France > Senegal - 81 (4.0%)
# France > Isle Bourbon & Isle of France - 76 (4.0%)
# France > India - 71 (3.0%)
# France > Senegal > France - 63 (3.0%)
#  - 43 (2.0%)
# France > ? - 38 (2.0%)
# France > Caribbean > France - 35 (2.0%)
# France > India > Isle Bourbon & Isle of France > France - 29 (1.0%)
# France > Isle Bourbon & Isle of France > France - 25 (1.0%)
# France > cabotage > France - 23 (1.0%)
# France > service des fermes > France - 23 (1.0%)
# France > India > France - 22 (1.0%)
# France > Louisiana - 21 (1.0%)
# France > Caribbean - 19 (1.0%)
# France > Louisiana > France - 17 (1.0%)
# France > ? > France - 16 (1.0%)
# France > India > Isle Bourbon & Isle of France - 16 (1.0%)
# France > Caribbean > Louisiana > France - 15 (1.0%)
# France > service des fermes - 14 (1.0%)
# France > Madagascar - 12 (1.0%)
# France > Caribbean > Louisiana > Caribbean > France - 12 (1.0%)
# France > Senegal > Caribbean - 12 (1.0%)
# France > India > Isle Bourbon & Isle of France > vaisseau de côte - 11 (1.0%)
# Hambourg > France - 11 (1.0%)
# France > Senegal > India > Isle Bourbon & Isle of France > Louisiana > France - 11 (1.0%)
# France > petit cabotage ? - 11 (1.0%)
# France > Senegal > Caribbean > Louisiana > France - 10 (0.0%)
# France > course ? - 10 (0.0%)
# France > Madagascar > India > Isle Bourbon & Isle of France > Louisiana > France - 10 (0.0%)
# Madagascar > France - 10 (0.0%)
# France > Caribbean > Madagascar - 9 (0.0%)
# France > Isle Bourbon & Isle of France > Chine > Isle Bourbon & Isle of France > France - 9 (0.0%)
# France > petit cabotage > France - 8 (0.0%)
# Senegal - 8 (0.0%)
# France > Cadix > Madagascar > India > Isle Bourbon & Isle of France > Louisiana > France - 8 (0.0%)
# Prise espagnole capturée à Pensacola - 7 (0.0%)
# France > India > Isle Bourbon & Isle of France > Cape of Good Hope > France - 7 (0.0%)
# Caribbean > France - 7 (0.0%)
# France > New France - 7 (0.0%)
# France > Cadix > India > Isle Bourbon & Isle of France > France - 7 (0.0%)
# France > Senegal > India > Isle Bourbon & Isle of France > France - 7 (0.0%)
# France > Caribbean > Louisiana - 7 (0.0%)
# France > Amérique ? - 6 (0.0%)
# France > aux ordres du roi > ? - 6 (0.0%)
# France > Cadix > France - 6 (0.0%)
# Isle Bourbon & Isle of France - 6 (0.0%)
# France > Isle Bourbon & Isle of France > India - 6 (0.0%)
# France > New France > France - 6 (0.0%)
# France > côte d’Afrique ? - 6 (0.0%)
# France > India > Isle Bourbon & Isle of France > Louisiana > France - 6 (0.0%)
# India > Isle Bourbon & Isle of France > India - 6 (0.0%)
# France > Chine > France - 6 (0.0%)
# France > Louisiana > Caribbean - 5 (0.0%)
# France > Isle Bourbon & Isle of France > Cape of Good Hope > France - 5 (0.0%)
# Isle Bourbon & Isle of France > France - 5 (0.0%)
# France > Cadix > India > Isle Bourbon & Isle of France > Louisiana > France - 5 (0.0%)
# France > Malaga > France - 5 (0.0%)
# France > cabotage ? - 5 (0.0%)
# France > grand cabotage > France - 5 (0.0%)
# France > Amérique > France - 5 (0.0%)
# France > Cape of Good Hope > Chine > Isle Bourbon & Isle of France > Louisiana > France - 5 (0.0%)
# France > Arguin > Senegal > France - 5 (0.0%)
# France > Cadix > Caribbean > France - 5 (0.0%)
# France > Senegal > Louisiana > France - 5 (0.0%)
# India > vaisseau de côte - 5 (0.0%)
# France > au devant des vaisseaux > France - 5 (0.0%)
# France > Senegal > La Corogne > France - 4 (0.0%)
# France > Chine ? - 4 (0.0%)
# Londres > France - 4 (0.0%)
# France > Senegal > Isle Bourbon & Isle of France > Louisiana > France - 4 (0.0%)
# France > Senegal > Isle Bourbon & Isle of France > vaisseau de côte - 4 (0.0%)
# Isle Bourbon & Isle of France > vaisseau de côte - 4 (0.0%)
# France > Brazil > India > Isle Bourbon & Isle of France > France - 4 (0.0%)
# France > Isle Bourbon & Isle of France > Madagascar - 4 (0.0%)
# France > Isle Bourbon & Isle of France > India > Isle Bourbon & Isle of France > France - 4 (0.0%)
# France > Isle Bourbon & Isle of France > Madagascar > France - 4 (0.0%)
# France > Angola > Caribbean > France - 4 (0.0%)
# France > Chine > Isle Bourbon & Isle of France > France - 4 (0.0%)
# France > Cape of Good Hope > India > Isle Bourbon & Isle of France > France - 4 (0.0%)
# France > Santiago > India > Isle Bourbon & Isle of France > Louisiana > France - 4 (0.0%)
# France > Vannes > Caribbean > France - 4 (0.0%)
# France > Madagascar > Isle Bourbon & Isle of France > France - 3 (0.0%)
# France > Brazil > Isle Bourbon & Isle of France > vaisseau de côte - 3 (0.0%)
# France > Cape of Good Hope > Isle Bourbon & Isle of France > France - 3 (0.0%)
# France > Cadix > Isle Bourbon & Isle of France > Chine > Isle Bourbon & Isle of France > Louisiana > France - 3 (0.0%)
# France > Madagascar > India > Isle Bourbon & Isle of France > France - 3 (0.0%)
# France > Senegal > India > Isle Bourbon & Isle of France > Sainte-Hélène > France - 3 (0.0%)
# France > Senegal > India > Isle Bourbon & Isle of France - 3 (0.0%)
# France > India > Sainte-Hélène > France - 3 (0.0%)
# France > Isle Bourbon & Isle of France > India > France - 3 (0.0%)
# France > Cabotage > France - 3 (0.0%)
# Madagascar > Caribbean - 3 (0.0%)
# France > Isle Bourbon & Isle of France > India > Cape of Good Hope > France - 3 (0.0%)
# France > Senegal > Madagascar > Isle Bourbon & Isle of France > Louisiana > France - 3 (0.0%)
# France > Senegal > Madagascar > Isle Bourbon & Isle of France > France - 3 (0.0%)
# France > India > Cape of Good Hope > France - 3 (0.0%)
# Madagascar > Louisiana > France - 3 (0.0%)
